# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Load the provided JSON file
file_path = 'one_scenario.json'
with open(file_path, 'r') as file:
    data = json.load(file)
    
data

# %%
data
# Out:
# {'PCV': {'Serum_Institute': {'5': {'78': 211694.73871447178},
#    '4': {'78': 40977.49851330882},
#    '6': {'78': 194163.93595228432},
#    '7': {'78': 211374.00128250686},
#    '2': {'78': 14507.405343596323},
#    '10': {'78': 38720.146536306405},
#    '9': {'78': 350351.8089790246},
#    '8': {'78': 332900.1243615941},
#    '3': {'78': 293910.8027244111},
#    '1': {'78': 0.0}},
#   'Pfizer': {'5': {'78': 46375.58523774384},
#    '4': {'78': 46091.653083227044},
#    '6': {'78': 46233.18323599028},
#    '7': {'78': 46304.27475301128},
#    '2': {'78': 45534.092763671884},
#    '10': {'78': 46277.58982807197},
#    '9': {'78': 46286.48138497502},
#    '8': {'78': 46268.70168661972},
#    '3': {'78': 46663.03721235796},
#    '1': {'78': 45534.092763671884}},
#   'GSK': {'5': {'78': 114059.67604778436},
#    '4': {'78': 112683.26182245932},
#    '6': {'78': 113398.8808117254},
#    '7': {'78': 112883.72396448185},
#    '2': {'78': 109912.36194157916},
# ...

# %%
# Function to aggregate data by year for each producer
def aggregate_data(data):
    aggregated = {}
    for vaccine, producers in data.items():
        for producer, years in producers.items():
            if producer not in aggregated:
                aggregated[producer] = {}
            for year, values in years.items():
                aggregated[producer][year] = sum(values.values())
    return aggregated

# Aggregate the data
aggregated_data = aggregate_data(data)

# Plot the aggregated data
plt.figure(figsize=(12, 8))
for producer, years in aggregated_data.items():
    years_sorted = sorted(years.items())
    years, values = zip(*years_sorted)
    plt.plot(years, values, marker='o', label=producer)

plt.xlabel('Year')
plt.ylabel('Aggregated Value')
plt.title('Aggregated Data per Producer per Year')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 13
#      10     return aggregated
#      12 # Aggregate the data
# ---> 13 aggregated_data = aggregate_data(data)
#      15 # Plot the aggregated data
#      16 plt.figure(figsize=(12, 8))
#
# Cell In[25], line 4, in aggregate_data(data)
#       2 def aggregate_data(data):
#       3     aggregated = {}
# ----> 4     for vaccine, producers in data.items():
#       5         for producer, years in producers.items():
#       6             if producer not in aggregated:
#
# AttributeError: 'list' object has no attribute 'items'

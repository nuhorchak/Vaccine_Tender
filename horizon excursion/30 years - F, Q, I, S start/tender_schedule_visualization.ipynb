# %%
import json
# import plotly.express as px
import pandas as pd
# import openpyxl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Tender schedule with starting point

# %%
with open('Deterministic_results_with_initial_conditions_30.json') as json_file:
    F_results = json.load(json_file)

# %%
# Search results by keyword for F (tender schedules)
# List of keywords to search for
keywords_to_search = ["F"]

# Initialize a dictionary to store grouped results
grouped_results = {keyword: [] for keyword in keywords_to_search}

# Search for keywords in the JSON keys and group the results
for key, value in F_results.items():
    for keyword in keywords_to_search:
        if keyword in key:
            grouped_results[keyword].append({key: value})

# %%
# create dictionary from F data from above
# Extracting information from the dictionary
data_list = []
for item in grouped_results['F']:
    key, value = list(item.items())[0]
    # print(key)
    tender = key.split('[', 1)[1].split(',', 1)[0]
    start, finish = eval(key.split('(', 1)[1].split(')', 1)[0])
    value = item[key]
    
    data_list.append({'Tender': tender, 'Start': start, 'Finish': finish, 'Value': value})

# Create a DataFrame
F_values_df = pd.DataFrame(data_list)

# remove ongoing tenders
F_values_df = F_values_df[(F_values_df.Start > 0) & (F_values_df.Value > 0)]

# %%
# Convert the 'Tender' column to a categorical data type with the specified order
F_values_df['Tender'] = pd.Categorical(F_values_df['Tender'], categories=tender_order, ordered=True)

# Sort the DataFrame based on 'Tender' and 'Start'
F_values_df = F_values_df.sort_values(['Tender', 'Start'])

# %%
F_values_df
# Out:
#          Tender  Start  Finish  Value
# 258     Measles      4       8    1.0
# 707     Measles      7      11    1.0
# 1029    Measles     12      16    1.0
# 634     Measles     17      21    1.0
# 751     Measles     22      26    1.0
# ...         ...    ...     ...    ...
# 905   Rotavirus      7      11    1.0
# 618   Rotavirus     12      16    1.0
# 471   Rotavirus     17      21    1.0
# 678   Rotavirus     22      26    1.0
# 202   Rotavirus     26      30    1.0
#
# [72 rows x 4 columns]

# %%
#check to make sure all tenders are accounted for in model results
def lists_contain_same_strings(list1, list2):
    return set(list1) == set(list2)

# Example usage
list_a = list(F_values_df.Tender.unique())
list_b = ["Measles","Mumps","Rubella","Diphtheria","Tetanus","Pertussis",
          "Hepatitis_B","Hib","Polio","HPV","Rotavirus","PCV"]

lists_contain_same_strings(list_a, list_b)
# Out:
# True

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Assuming F_values_df is your DataFrame containing data

# Define the desired order
tender_order = ['Measles', 'Mumps', 'Rubella', 'Diphtheria', 'Tetanus', 'Pertussis', 'Hib', 'Polio', 'Hepatitis_B','HPV', 'PCV', 'Rotavirus']

# Define color groups
color_groups = {
    'M/MR/MMR': ['Measles', 'Mumps', 'Rubella'],
    'Penta/Hexa/Others': ['Diphtheria', 'Tetanus', 'Pertussis', 'Hib', 'Polio', 'Hepatitis_B'],
    'HPV': ['HPV'],
    'PCV': ['PCV'],
    'Rota': ['Rotavirus'],
}

# Convert the 'Tender' column to a categorical data type with the specified order
F_values_df['Tender'] = pd.Categorical(F_values_df['Tender'], categories=tender_order, ordered=True)

# Sort the DataFrame based on the categorical order
F_values_df = F_values_df.sort_values('Tender')

# fig, ax = plt.subplots(figsize=(10, 5))
fig, ax = plt.subplots(figsize=(12, 8))  # Adjust figure size

# Define colors for each group
colors = {
    'M/MR/MMR': 'blue',
    'Penta/Hexa/Others': 'green',
    'HPV': 'red',
    'PCV': 'purple',
    'Rota': 'orange',
}

# Iterate through rows and plot bars based on conditions and color groups
for index, row in F_values_df.iterrows():
    if round(row['Value']) == 1:
        start = row['Start'] - 1
        end = row['Finish']
        
        # Choose color based on the group
        for group, tenders in color_groups.items():
            if row['Tender'] in tenders:
                color = colors[group]
                
                # Convert 'Tender' values to numerical indices before adding jitter
                tender_index = tender_order.index(row['Tender'])
                
                # Add jitter to y-coordinates by introducing random noise
                jitter = np.random.uniform(low=0, high=0.2)
                ax.barh(tender_index + jitter, width=end - start, left=start, edgecolor='black', color=color)

# Set labels and show the plot
ax.set_yticks(range(len(tender_order)))
ax.set_yticklabels(tender_order)

ax.set_xlim(0, 30)
ax.set_xticks(range(31))

ax.set_xlabel('Antigen Tender Schedule')
ax.set_ylabel('Antigen')
plt.title('Deterministic Tender Schedule with Horizon - 10 Year')

# Create a legend with adjusted location
legend_labels = [plt.Rectangle((0,0),1,1, color=colors[group], label=group) for group in color_groups.keys()]
ax.legend(legend_labels, color_groups.keys(), loc='upper left', bbox_to_anchor=(1, 1))

# Add a dashed yellow line at the 10th tick on the x-axis
# ax.axvline(x=10.04, color='yellow', linestyle='--', linewidth=2)

# Save and show the plot
plt.savefig('deterministic_horizon_with_start_30_jittered_y.png', bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
# Search results by keyword for F (tender schedules)
# List of keywords to search for
keywords_to_search = ["L["]

# Initialize a dictionary to store grouped results
grouped_results = {keyword: [] for keyword in keywords_to_search}

# Search for keywords in the JSON keys and group the results
for key, value in F_results.items():
    for keyword in keywords_to_search:
        if keyword in key:
            grouped_results[keyword].append({key: value})

# %%
grouped_results
# Out:
# {'L[': [{'L[PT_Bio,1]': 1.0},
#   {'L[Bharat_Biotech,6]': 0.0},
#   {'L[BB_NCIPD,19]': 0.0},
#   {'L[Bharat_Biotech,20]': 0.0},
#   {'L[Bilthoven,10]': 0.0},
#   {'L[Bharat_Biotech,4]': 0.0},
#   {'L[GSK,27]': 0.0},
#   {'L[Merck_Sharp,16]': 0.0},
#   {'L[LG_Chem,15]': 0.0},
#   {'L[LG_Chem,3]': 0.0},
#   {'L[GSK,20]': 0.0},
#   {'L[BB_NCIPD,18]': 0.0},
#   {'L[Centro_de,9]': 0.0},
#   {'L[Serum_Institute,28]': 0.0},
#   {'L[Panacea_Biotec,20]': 0.0},
#   {'L[Bharat_Biotech,13]': 0.0},
#   {'L[Bilthoven,19]': 0.0},
#   {'L[LG_Chem,12]': 0.0},
#   {'L[Merck_Sharp,12]': 0.0},
#   {'L[Haffkine_Bio,26]': 0.0},
#   {'L[Serum_Institute,14]': 0.0},
#   {'L[Centro_de,5]': 0.0},
#   {'L[PT_Bio,29]': 0.0},
#   {'L[PT_Bio,7]': 0.0},
#   {'L[Biological_E,30]': 0.0},
#   {'L[Sanofi_Pasteur,13]': 0.0},
#   {'L[Haffkine_Bio,3]': 0.0},
#   {'L[Biological_E,14]': 0.0},
#   {'L[Sanofi_Pasteur,10]': 0.0},
#   {'L[Serum_Institute,22]': 0.0},
#   {'L[BB_NCIPD,10]': 0.0},
#   {'L[GSK,30]': 0.0},
#   {'L[PT_Bio,14]': 0.0},
#   {'L[Bilthoven,11]': 0.0},
#   {'L[Biological_E,25]': 0.0},
#   {'L[Biological_E,15]': 0.0},
#   {'L[Beijing_Institute,18]': 0.0},
#   {'L[Merck_Sharp,22]': 0.0},
#   {'L[Sanofi_Pasteur,20]': 0.0},
#   {'L[Merck_Sharp,30]': 0.0},
#   {'L[Bilthoven,18]': 0.0},
#   {'L[Panacea_Biotec,12]': 0.0},
#   {'L[GSK,14]': 0.0},
#   {'L[Xiamen_Innovax,6]': 0.0},
#   {'L[GSK,11]': 0.0},
#   {'L[LG_Chem,19]': 0.0},
#   {'L[AJ_Vaccines,11]': 0.0},
#   {'L[Bilthoven,27]': 0.0},
#   {'L[Merck_Sharp,8]': 0.0},
#   {'L[LG_Chem,6]': 0.0},
#   {'L[Haffkine_Bio,5]': 0.0},
#   {'L[Centro_de,15]': 0.0},
#   {'L[Pfizer,24]': 0.0},
#   {'L[Panacea_Biotec,2]': 0.0},
#   {'L[Haffkine_Bio,24]': 0.0},
#   {'L[LG_Chem,23]': 0.0},
#   {'L[Beijing_Institute,8]': 0.0},
#   {'L[BB_NCIPD,1]': 1.0},
#   {'L[Bharat_Biotech,3]': 0.0},
#   {'L[Sanofi_Pasteur,15]': 0.0},
#   {'L[Xiamen_Innovax,19]': 0.0},
#   {'L[Bharat_Biotech,24]': 0.0},
#   {'L[Xiamen_Innovax,26]': 0.0},
#   {'L[Pfizer,2]': 0.0},
#   {'L[GSK,4]': 0.0},
#   {'L[PT_Bio,16]': 0.0},
#   {'L[Bilthoven,1]': 0.0},
#   {'L[Panacea_Biotec,29]': 0.0},
#   {'L[Panacea_Biotec,17]': 0.0},
#   {'L[Beijing_Institute,1]': 0.0},
#   {'L[Biological_E,27]': 0.0},
#   {'L[Bharat_Biotech,10]': 0.0},
#   {'L[Panacea_Biotec,21]': 0.0},
#   {'L[Haffkine_Bio,23]': 0.0},
#   {'L[PT_Bio,20]': 0.0},
#   {'L[Sanofi_Pasteur,1]': 0.0},
#   {'L[Bilthoven,29]': 0.0},
#   {'L[Beijing_Institute,12]': 0.0},
#   {'L[Sanofi_Pasteur,28]': 0.0},
#   {'L[LG_Chem,4]': 0.0},
#   {'L[Panacea_Biotec,5]': 0.0},
#   {'L[GSK,9]': 0.0},
#   {'L[Bilthoven,20]': 0.0},
#   {'L[PT_Bio,4]': 0.0},
#   {'L[BB_NCIPD,7]': 0.0},
#   {'L[Beijing_Institute,5]': 0.0},
#   {'L[Sanofi_Pasteur,11]': 0.0},
#   {'L[Beijing_Institute,19]': 0.0},
#   {'L[BB_NCIPD,28]': 0.0},
#   {'L[Pfizer,16]': 0.0},
#   {'L[Serum_Institute,9]': 0.0},
#   {'L[Biological_E,19]': 0.0},
#   {'L[Panacea_Biotec,15]': 0.0},
#   {'L[Haffkine_Bio,16]': 0.0},
#   {'L[Merck_Sharp,21]': 0.0},
#   {'L[AJ_Vaccines,18]': 0.0},
#   {'L[PT_Bio,9]': 0.0},
#   {'L[Centro_de,2]': 0.0},
#   {'L[Bharat_Biotech,22]': 0.0},
#   {'L[Sanofi_Pasteur,22]': 0.0},
#   {'L[Panacea_Biotec,11]': 0.0},
#   {'L[GSK,2]': 0.0},
#   {'L[Bharat_Biotech,25]': 0.0},
#   {'L[Panacea_Biotec,23]': 0.0},
#   {'L[Haffkine_Bio,19]': 0.0},
#   {'L[AJ_Vaccines,13]': 0.0},
#   {'L[Centro_de,23]': 0.0},
#   {'L[Sanofi_Pasteur,25]': 0.0},
#   {'L[Beijing_Institute,16]': 0.0},
#   {'L[PT_Bio,23]': 0.0},
#   {'L[Serum_Institute,3]': 1.0},
#   {'L[PT_Bio,22]': 0.0},
#   {'L[Bharat_Biotech,11]': 0.0},
#   {'L[Haffkine_Bio,14]': 0.0},
#   {'L[LG_Chem,8]': 0.0},
#   {'L[Centro_de,28]': 0.0},
#   {'L[LG_Chem,22]': 0.0},
#   {'L[Beijing_Institute,10]': 0.0},
#   {'L[AJ_Vaccines,28]': 0.0},
#   {'L[Biological_E,2]': 0.0},
#   {'L[Bilthoven,7]': 0.0},
#   {'L[Panacea_Biotec,1]': 1.0},
#   {'L[Xiamen_Innovax,17]': 0.0},
#   {'L[Pfizer,18]': 0.0},
#   {'L[Biological_E,9]': 0.0},
#   {'L[Bharat_Biotech,2]': 0.0},
#   {'L[Sanofi_Pasteur,30]': 0.0},
#   {'L[Beijing_Institute,4]': 0.0},
#   {'L[BB_NCIPD,24]': 0.0},
#   {'L[BB_NCIPD,8]': 0.0},
#   {'L[Serum_Institute,17]': 0.0},
#   {'L[PT_Bio,27]': 0.0},
#   {'L[Centro_de,22]': 0.0},
#   {'L[Biological_E,5]': 0.0},
#   {'L[Beijing_Institute,17]': 0.0},
#   {'L[Centro_de,18]': 0.0},
#   {'L[Pfizer,22]': 0.0},
#   {'L[Panacea_Biotec,8]': 0.0},
#   {'L[LG_Chem,29]': 0.0},
#   {'L[Merck_Sharp,26]': 0.0},
#   {'L[Sanofi_Pasteur,9]': 0.0},
#   {'L[Centro_de,14]': 0.0},
#   {'L[Beijing_Institute,23]': 0.0},
#   {'L[Pfizer,20]': 0.0},
#   {'L[Sanofi_Pasteur,18]': 0.0},
#   {'L[Merck_Sharp,4]': 0.0},
#   {'L[Pfizer,17]': 0.0},
#   {'L[Haffkine_Bio,4]': 0.0},
#   {'L[Biological_E,29]': 0.0},
#   {'L[BB_NCIPD,14]': 0.0},
#   {'L[BB_NCIPD,23]': 0.0},
#   {'L[LG_Chem,25]': 0.0},
#   {'L[BB_NCIPD,12]': 0.0},
#   {'L[Beijing_Institute,30]': 0.0},
#   {'L[Haffkine_Bio,12]': 0.0},
#   {'L[Xiamen_Innovax,15]': 0.0},
#   {'L[GSK,26]': 0.0},
#   {'L[Beijing_Institute,22]': 0.0},
#   {'L[Bharat_Biotech,16]': 0.0},
#   {'L[Serum_Institute,19]': 0.0},
#   {'L[Haffkine_Bio,13]': 0.0},
#   {'L[GSK,25]': 0.0},
#   {'L[Centro_de,19]': 0.0},
#   {'L[Sanofi_Pasteur,8]': 0.0},
#   {'L[Serum_Institute,21]': 0.0},
#   {'L[BB_NCIPD,17]': 0.0},
#   {'L[Pfizer,12]': 0.0},
#   {'L[PT_Bio,26]': 0.0},
#   {'L[Biological_E,3]': 0.0},
#   {'L[AJ_Vaccines,24]': 0.0},
#   {'L[Serum_Institute,29]': 0.0},
#   {'L[Beijing_Institute,24]': 0.0},
#   {'L[Serum_Institute,23]': 0.0},
#   {'L[Xiamen_Innovax,28]': 0.0},
#   {'L[GSK,6]': 0.0},
#   {'L[Pfizer,8]': 0.0},
#   {'L[LG_Chem,5]': 0.0},
#   {'L[Bilthoven,6]': 0.0},
#   {'L[PT_Bio,28]': 0.0},
#   {'L[Serum_Institute,18]': 0.0},
#   {'L[GSK,12]': 0.0},
#   {'L[BB_NCIPD,16]': 0.0},
#   {'L[GSK,16]': 0.0},
#   {'L[Biological_E,16]': 0.0},
#   {'L[Xiamen_Innovax,5]': 0.0},
#   {'L[Pfizer,5]': 0.0},
#   {'L[Xiamen_Innovax,4]': 0.0},
#   {'L[Panacea_Biotec,16]': 0.0},
#   {'L[Bharat_Biotech,1]': 0.0},
#   {'L[LG_Chem,26]': 0.0},
#   {'L[LG_Chem,24]': 0.0},
#   {'L[Serum_Institute,24]': 0.0},
#   {'L[Bharat_Biotech,14]': 0.0},
#   {'L[Pfizer,25]': 0.0},
#   {'L[Merck_Sharp,6]': 0.0},
#   {'L[Panacea_Biotec,13]': 0.0},
#   {'L[Centro_de,10]': 0.0},
#   {'L[Haffkine_Bio,11]': 0.0},
#   {'L[Centro_de,24]': 0.0},
#   {'L[Xiamen_Innovax,14]': 0.0},
#   {'L[Merck_Sharp,27]': 0.0},
#   {'L[LG_Chem,9]': 0.0},
#   {'L[Centro_de,4]': 0.0},
#   {'L[Sanofi_Pasteur,2]': 0.0},
#   {'L[Panacea_Biotec,19]': 0.0},
#   {'L[Xiamen_Innovax,22]': 0.0},
#   {'L[Haffkine_Bio,29]': 0.0},
#   {'L[Pfizer,6]': 0.0},
#   {'L[Beijing_Institute,29]': 0.0},
#   {'L[BB_NCIPD,13]': 0.0},
#   {'L[Panacea_Biotec,27]': 0.0},
#   {'L[BB_NCIPD,11]': 0.0},
#   {'L[GSK,18]': 0.0},
#   {'L[Serum_Institute,1]': 1.0},
#   {'L[PT_Bio,13]': 0.0},
#   {'L[Pfizer,28]': 0.0},
#   {'L[AJ_Vaccines,16]': 0.0},
#   {'L[PT_Bio,15]': 0.0},
#   {'L[Bharat_Biotech,12]': 0.0},
#   {'L[Merck_Sharp,14]': 0.0},
#   {'L[GSK,13]': 0.0},
#   {'L[Panacea_Biotec,14]': 0.0},
#   {'L[Haffkine_Bio,27]': 0.0},
#   {'L[PT_Bio,25]': 0.0},
#   {'L[GSK,24]': 0.0},
#   {'L[Merck_Sharp,28]': 0.0},
#   {'L[Biological_E,22]': 0.0},
#   {'L[GSK,7]': 0.0},
#   {'L[Bharat_Biotech,27]': 0.0},
#   {'L[Xiamen_Innovax,21]': 0.0},
#   {'L[Xiamen_Innovax,29]': 0.0},
#   {'L[Serum_Institute,25]': 0.0},
#   {'L[Haffkine_Bio,2]': 0.0},
#   {'L[Serum_Institute,7]': 0.0},
#   {'L[Sanofi_Pasteur,21]': 0.0},
#   {'L[PT_Bio,3]': 0.0},
#   {'L[BB_NCIPD,9]': 0.0},
#   {'L[Serum_Institute,4]': 1.0},
#   {'L[AJ_Vaccines,12]': 0.0},
#   {'L[Pfizer,23]': 0.0},
#   {'L[Biological_E,26]': 0.0},
#   {'L[Bilthoven,28]': 0.0},
#   {'L[PT_Bio,30]': 0.0},
#   {'L[Merck_Sharp,1]': 0.0},
#   {'L[Xiamen_Innovax,24]': 0.0},
#   {'L[Pfizer,10]': 0.0},
#   {'L[Serum_Institute,20]': 0.0},
#   {'L[GSK,3]': 0.0},
#   {'L[Serum_Institute,15]': 0.0},
#   {'L[Bharat_Biotech,30]': 0.0},
#   {'L[GSK,1]': 0.0},
#   {'L[Pfizer,9]': 0.0},
#   {'L[LG_Chem,21]': 0.0},
#   {'L[Beijing_Institute,7]': 0.0},
#   {'L[Haffkine_Bio,22]': 0.0},
#   {'L[Bilthoven,8]': 0.0},
#   {'L[BB_NCIPD,29]': 0.0},
#   {'L[Centro_de,27]': 0.0},
#   {'L[BB_NCIPD,5]': 0.0},
#   {'L[BB_NCIPD,15]': 0.0},
#   {'L[Bharat_Biotech,19]': 0.0},
#   {'L[Pfizer,4]': 0.0},
#   {'L[Sanofi_Pasteur,14]': 0.0},
#   {'L[AJ_Vaccines,23]': 0.0},
#   {'L[BB_NCIPD,26]': 0.0},
#   {'L[Biological_E,4]': 0.0},
#   {'L[Centro_de,30]': 0.0},
#   {'L[Bilthoven,24]': 0.0},
#   {'L[Sanofi_Pasteur,4]': 0.0},
#   {'L[Bharat_Biotech,5]': 0.0},
#   {'L[PT_Bio,12]': 0.0},
#   {'L[Pfizer,26]': 0.0},
#   {'L[GSK,21]': 0.0},
#   {'L[Haffkine_Bio,18]': 0.0},
#   {'L[GSK,15]': 0.0},
#   {'L[PT_Bio,21]': 0.0},
#   {'L[Haffkine_Bio,9]': 0.0},
#   {'L[AJ_Vaccines,14]': 0.0},
#   {'L[Bilthoven,12]': 0.0},
#   {'L[Bilthoven,14]': 0.0},
#   {'L[Centro_de,16]': 0.0},
#   {'L[Beijing_Institute,11]': 0.0},
#   {'L[Xiamen_Innovax,20]': 0.0},
#   {'L[Panacea_Biotec,30]': 0.0},
#   {'L[AJ_Vaccines,10]': 0.0},
#   {'L[Biological_E,1]': 1.0},
#   {'L[Merck_Sharp,24]': 0.0},
#   {'L[Sanofi_Pasteur,6]': 0.0},
#   {'L[Pfizer,11]': 0.0},
#   {'L[Merck_Sharp,15]': 0.0},
#   {'L[Panacea_Biotec,24]': 0.0},
#   {'L[Centro_de,7]': 0.0},
#   {'L[Beijing_Institute,15]': 0.0},
#   {'L[Centro_de,11]': 0.0},
#   {'L[AJ_Vaccines,6]': 0.0},
#   {'L[Panacea_Biotec,7]': 0.0},
#   {'L[Beijing_Institute,28]': 0.0},
#   {'L[Xiamen_Innovax,12]': 0.0},
#   {'L[Merck_Sharp,20]': 0.0},
#   {'L[Biological_E,23]': 0.0},
#   {'L[Sanofi_Pasteur,12]': 0.0},
#   {'L[Haffkine_Bio,15]': 0.0},
#   {'L[Xiamen_Innovax,11]': 0.0},
#   {'L[Sanofi_Pasteur,16]': 0.0},
#   {'L[BB_NCIPD,22]': 0.0},
#   {'L[Beijing_Institute,21]': 0.0},
#   {'L[Haffkine_Bio,10]': 0.0},
#   {'L[Xiamen_Innovax,23]': 0.0},
#   {'L[BB_NCIPD,4]': 0.0},
#   {'L[Xiamen_Innovax,25]': 0.0},
#   {'L[Bharat_Biotech,23]': 0.0},
#   {'L[AJ_Vaccines,2]': 0.0},
#   {'L[AJ_Vaccines,29]': 0.0},
#   {'L[Beijing_Institute,26]': 0.0},
#   {'L[Pfizer,19]': 0.0},
#   {'L[GSK,22]': 0.0},
#   {'L[Biological_E,24]': 0.0},
#   {'L[Beijing_Institute,2]': 0.0},
#   {'L[Bharat_Biotech,17]': 0.0},
#   {'L[Serum_Institute,27]': 0.0},
#   {'L[Centro_de,3]': 0.0},
#   {'L[AJ_Vaccines,9]': 0.0},
#   {'L[Merck_Sharp,9]': 0.0},
#   {'L[Xiamen_Innovax,2]': 0.0},
#   {'L[Merck_Sharp,7]': 0.0},
#   {'L[PT_Bio,18]': 0.0},
#   {'L[Haffkine_Bio,17]': 0.0},
#   {'L[Pfizer,21]': 0.0},
#   {'L[Serum_Institute,26]': 0.0},
#   {'L[Pfizer,1]': 0.0},
#   {'L[BB_NCIPD,3]': 0.0},
#   {'L[Bharat_Biotech,28]': 0.0},
#   {'L[Panacea_Biotec,10]': 0.0},
#   {'L[Biological_E,18]': 0.0},
#   {'L[Sanofi_Pasteur,24]': 0.0},
#   {'L[Centro_de,17]': 0.0},
#   {'L[PT_Bio,19]': 0.0},
#   {'L[Bilthoven,16]': 0.0},
#   {'L[Pfizer,30]': 0.0},
#   {'L[LG_Chem,27]': 0.0},
#   {'L[LG_Chem,10]': 0.0},
#   {'L[PT_Bio,11]': 0.0},
#   {'L[Centro_de,12]': 0.0},
#   {'L[PT_Bio,6]': 0.0},
#   {'L[Biological_E,17]': 0.0},
#   {'L[Serum_Institute,2]': 1.0},
#   {'L[Bilthoven,22]': 0.0},
#   {'L[GSK,8]': 0.0},
#   {'L[Merck_Sharp,29]': 0.0},
#   {'L[Centro_de,13]': 0.0},
#   {'L[Xiamen_Innovax,13]': 0.0},
#   {'L[LG_Chem,11]': 0.0},
#   {'L[Xiamen_Innovax,7]': 0.0},
#   {'L[GSK,10]': 0.0},
#   {'L[Xiamen_Innovax,10]': 0.0},
#   {'L[LG_Chem,16]': 0.0},
#   {'L[Beijing_Institute,3]': 0.0},
#   {'L[AJ_Vaccines,22]': 0.0},
#   {'L[Panacea_Biotec,25]': 0.0},
#   {'L[BB_NCIPD,30]': 0.0},
#   {'L[Centro_de,25]': 0.0},
#   {'L[GSK,28]': 0.0},
#   {'L[Pfizer,27]': 0.0},
#   {'L[AJ_Vaccines,21]': 0.0},
#   {'L[Merck_Sharp,2]': 0.0},
#   {'L[Bilthoven,4]': 0.0},
#   {'L[Panacea_Biotec,4]': 0.0},
#   {'L[LG_Chem,1]': 1.0},
#   {'L[Xiamen_Innovax,18]': 0.0},
#   {'L[Panacea_Biotec,3]': 0.0},
#   {'L[Bilthoven,23]': 0.0},
#   {'L[Beijing_Institute,20]': 0.0},
#   {'L[Merck_Sharp,19]': 0.0},
#   {'L[Sanofi_Pasteur,5]': 0.0},
#   {'L[Haffkine_Bio,25]': 0.0},
#   {'L[GSK,23]': 0.0},
#   {'L[LG_Chem,7]': 0.0},
#   {'L[PT_Bio,24]': 0.0},
#   {'L[LG_Chem,28]': 0.0},
#   {'L[PT_Bio,17]': 0.0},
#   {'L[LG_Chem,30]': 0.0},
#   {'L[Bilthoven,30]': 0.0},
#   {'L[AJ_Vaccines,17]': 0.0},
#   {'L[Haffkine_Bio,6]': 0.0},
#   {'L[Biological_E,21]': 0.0},
#   {'L[Pfizer,15]': 0.0},
#   {'L[Merck_Sharp,10]': 0.0},
#   {'L[BB_NCIPD,2]': 0.0},
#   {'L[Bilthoven,17]': 0.0},
#   {'L[BB_NCIPD,27]': 0.0},
#   {'L[Merck_Sharp,13]': 0.0},
#   {'L[Bharat_Biotech,26]': 0.0},
#   {'L[LG_Chem,17]': 0.0},
#   {'L[AJ_Vaccines,30]': 0.0},
#   {'L[LG_Chem,14]': 0.0},
#   {'L[Sanofi_Pasteur,26]': 0.0},
#   {'L[LG_Chem,13]': 0.0},
#   {'L[Bilthoven,26]': 0.0},
#   {'L[BB_NCIPD,6]': 0.0},
#   {'L[Bharat_Biotech,9]': 0.0},
#   {'L[AJ_Vaccines,7]': 0.0},
#   {'L[AJ_Vaccines,20]': 0.0},
#   {'L[Beijing_Institute,6]': 0.0},
#   {'L[Biological_E,20]': 0.0},
#   {'L[Merck_Sharp,18]': 0.0},
#   {'L[Centro_de,8]': 0.0},
#   {'L[Xiamen_Innovax,3]': 0.0},
#   {'L[Haffkine_Bio,28]': 0.0},
#   {'L[Biological_E,6]': 0.0},
#   {'L[AJ_Vaccines,15]': 0.0},
#   {'L[Xiamen_Innovax,9]': 0.0},
#   {'L[Serum_Institute,12]': 0.0},
#   {'L[Pfizer,29]': 0.0},
#   {'L[Biological_E,13]': 0.0},
#   {'L[Haffkine_Bio,1]': 0.0},
#   {'L[AJ_Vaccines,5]': 0.0},
#   {'L[PT_Bio,5]': 0.0},
#   {'L[Bilthoven,9]': 0.0},
#   {'L[Serum_Institute,10]': 0.0},
#   {'L[Sanofi_Pasteur,23]': 0.0},
#   {'L[AJ_Vaccines,3]': 0.0},
#   {'L[BB_NCIPD,25]': 0.0},
#   {'L[Sanofi_Pasteur,7]': 0.0},
#   {'L[Centro_de,29]': 0.0},
#   {'L[Pfizer,3]': 0.0},
#   {'L[GSK,17]': 0.0},
#   {'L[Beijing_Institute,13]': 0.0},
#   {'L[Biological_E,7]': 0.0},
#   {'L[GSK,5]': 0.0},
#   {'L[Serum_Institute,30]': 0.0},
#   {'L[Panacea_Biotec,6]': 0.0},
#   {'L[Xiamen_Innovax,30]': 0.0},
#   {'L[Serum_Institute,13]': 0.0},
#   {'L[Centro_de,26]': 0.0},
#   {'L[Pfizer,7]': 0.0},
#   {'L[LG_Chem,20]': 0.0},
#   {'L[Haffkine_Bio,30]': 0.0},
#   {'L[Pfizer,14]': 0.0},
#   {'L[AJ_Vaccines,26]': 0.0},
#   {'L[Panacea_Biotec,26]': 0.0},
#   {'L[LG_Chem,2]': 0.0},
#   {'L[PT_Bio,2]': 0.0},
#   {'L[Bilthoven,21]': 0.0},
#   {'L[BB_NCIPD,21]': 0.0},
#   {'L[Bharat_Biotech,29]': 0.0},
#   {'L[Sanofi_Pasteur,29]': 0.0},
#   {'L[Merck_Sharp,3]': 0.0},
#   {'L[Haffkine_Bio,7]': 0.0},
#   {'L[Haffkine_Bio,20]': 0.0},
#   {'L[Bilthoven,5]': 0.0},
#   {'L[Panacea_Biotec,28]': 0.0},
#   {'L[Xiamen_Innovax,27]': 0.0},
#   {'L[Xiamen_Innovax,8]': 0.0},
#   {'L[Biological_E,12]': 0.0},
#   {'L[Bharat_Biotech,8]': 0.0},
#   {'L[Beijing_Institute,14]': 0.0},
#   {'L[Serum_Institute,6]': 0.0},
#   {'L[Sanofi_Pasteur,19]': 0.0},
#   {'L[Serum_Institute,5]': 0.0},
#   {'L[Pfizer,13]': 0.0},
#   {'L[Bilthoven,25]': 0.0},
#   {'L[LG_Chem,18]': 0.0},
#   {'L[Serum_Institute,8]': 0.0},
#   {'L[Centro_de,6]': 0.0},
#   {'L[Sanofi_Pasteur,17]': 0.0},
#   {'L[Centro_de,20]': 0.0},
#   {'L[BB_NCIPD,20]': 0.0},
#   {'L[Bharat_Biotech,7]': 0.0},
#   {'L[Xiamen_Innovax,16]': 0.0},
#   {'L[Panacea_Biotec,9]': 0.0},
#   {'L[Haffkine_Bio,8]': 0.0},
#   {'L[Panacea_Biotec,18]': 0.0},
#   {'L[PT_Bio,8]': 0.0},
#   {'L[AJ_Vaccines,25]': 0.0},
#   {'L[Merck_Sharp,23]': 0.0},
#   {'L[Sanofi_Pasteur,27]': 0.0},
#   {'L[Bilthoven,13]': 0.0},
#   {'L[Centro_de,1]': 0.0},
#   {'L[Xiamen_Innovax,1]': 0.0},
#   {'L[Biological_E,11]': 0.0},
#   {'L[AJ_Vaccines,27]': 0.0},
#   {'L[Merck_Sharp,17]': 0.0},
#   {'L[GSK,19]': 0.0},
#   {'L[Bharat_Biotech,18]': 0.0},
#   {'L[AJ_Vaccines,4]': 0.0},
#   {'L[Merck_Sharp,25]': 0.0},
#   {'L[Serum_Institute,16]': 0.0},
#   {'L[Merck_Sharp,5]': 0.0},
#   {'L[PT_Bio,10]': 0.0},
#   {'L[Biological_E,10]': 0.0},
#   {'L[Centro_de,21]': 0.0},
#   {'L[AJ_Vaccines,19]': 0.0},
#   {'L[Bilthoven,2]': 0.0},
#   {'L[Beijing_Institute,27]': 0.0},
#   {'L[Haffkine_Bio,21]': 0.0},
#   {'L[Serum_Institute,11]': 0.0},
#   {'L[Beijing_Institute,9]': 0.0},
#   {'L[Bilthoven,3]': 0.0},
#   {'L[Bharat_Biotech,21]': 0.0},
#   {'L[Bilthoven,15]': 0.0},
#   {'L[AJ_Vaccines,1]': 0.0},
#   {'L[Beijing_Institute,25]': 0.0},
#   {'L[Panacea_Biotec,22]': 0.0},
#   {'L[Sanofi_Pasteur,3]': 0.0},
#   {'L[AJ_Vaccines,8]': 0.0},
#   {'L[Bharat_Biotech,15]': 0.0},
#   {'L[Merck_Sharp,11]': 0.0},
#   {'L[Biological_E,8]': 0.0},
#   {'L[Biological_E,28]': 0.0},
#   {'L[GSK,29]': 0.0}]}

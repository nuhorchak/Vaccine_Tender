# %%
A = ["Measles","Mumps","Rubella"]
V = ["M","MR","MMR"]

A_v = Dict("Measles" => ["Measles"], "Measles-Rubella" => ["Measles","Rubella"], "Measles-Mumps-Rubella" => ["Measles","Mumps", "Rubella"])

V_a = Dict()
for a in A
    vector_a = []
    for v in keys(A_v)
        if a in A_v[v]
            push!(vector_a, v)
        end
    end
    V_a[a] = vector_a
end

P = ["Serum Institute of India","PT Bio Farma", "GlaxoSmithKline", "Merck Sharp & Dohme", "Biological E. Limited"]
P_v = Dict("Measles" => ["Serum Institute of India", "PT Bio Farma"],"Measles-Rubella" => ["Serum Institute of India", "Biological E. Limited"], "Measles-Mumps-Rubella" => ["Serum Institute of India","GlaxoSmithKline", "Merck Sharp & Dohme"])

V_p = Dict()
for p in P
    vector_p = []
    for v in keys(P_v)
        if p in P_v[v]
            push!(vector_p, v)
        end
    end
    V_p[p] = vector_p
end

tmin = 1
tmax = 5
T = [t for t in tmin:tmax]
T_initial = [t for t in tmin-1:tmax]
# Out:
# 6-element Vector{Int64}:
#  0
#  1
#  2
#  3
#  4
#  5

# %%
for key in sort(collect(keys(P_v)))
    println(key, P_v[key])
end
# Out:
# Measles["Serum Institute of India", "PT Bio Farma"]
# Measles-Mumps-Rubella["Serum Institute of India", "GlaxoSmithKline", "Merck Sharp & Dohme"]
# Measles-Rubella["Serum Institute of India", "Biological E. Limited"]

# %%
for (key, value) in P_v
    println(key, value)
end
# Out:
# Measles-Rubella["Serum Institute of India", "Biological E. Limited"]
# Measles["Serum Institute of India", "PT Bio Farma"]
# Measles-Mumps-Rubella["Serum Institute of India", "GlaxoSmithKline", "Merck Sharp & Dohme"]

# %%
Measles = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "P.T. Bio Farma" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])
Measles-Rubella = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "Biological E. Limited" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])
Measles-Mumps-Rubella = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "GlaxoSmithKline" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024], "Merck Sharp & Dohme" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])
#r_actual
# Out:
# Dict{String, Vector{Float64}} with 2 entries:
#   "P.T. Bio Farma"           => [0.2864, 0.2953, 0.3042, 0.3131, 0.024]
#   "Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405]

# %%
#r_rand = [5 2; 5 2; 8 8;;; 5 2; 5 2; 8 8;;; 10 4; 10 4; 15 15;;; 10 4; 10 4; 15 15;;; 20 8; 20 8; 30 30
r_actual = []
r = Dict()
for key in sort(collect(keys(P_v)))
    println("vaccine: $key")
    for v in P_v[key]
        println("producer: $v")
        for t in 1:length(T)
            println("time: $t")
            #r[V[v],P[p],T[t]] = r_rand[v,p,t]
        end
    end
end
# Out:
# vaccine: Measles
# producer: Serum Institute of India
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# producer: PT Bio Farma
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# vaccine: Measles-Mumps-Rubella
# producer: Serum Institute of India
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# producer: GlaxoSmithKline
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# producer: Merck Sharp & Dohme
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# vaccine: Measles-Rubella
# producer: Serum Institute of India
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5
# producer: Biological E. Limited
# time: 1
# time: 2
# time: 3
# time: 4
# time: 5

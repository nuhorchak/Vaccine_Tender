# %%
using XLSX
using DataFrames

# %%
A = ["Measles","Mumps","Rubella"]
V = ["M","MR","MMR"]

A_v = Dict("M" => ["Measles"], "MR" => ["Measles","Rubella"], "MMR" => ["Measles","Mumps", "Rubella"])

V_a = Dict()
for a in A
    vector_a = []
    for v in keys(A_v)
        if a in A_v[v]
            push!(vector_a, v)
        end
    end
    V_a[a] = vector_a
end

P = ["Serum Institute of India","PT Bio Farma", "GlaxoSmithKline", "Merck Sharp & Dohme", "Biological E. Limited"]
P_v = Dict("M" => ["Serum Institute of India", "PT Bio Farma"],"MR" => ["Serum Institute of India", "Biological E. Limited"], "MMR" => ["Serum Institute of India","GlaxoSmithKline", "Merck Sharp & Dohme"])

V_p = Dict()
for p in P
    vector_p = []
    for v in keys(P_v)
        if p in P_v[v]
            push!(vector_p, v)
        end
    end
    V_p[p] = vector_p
end

tmin = 1
tmax = 5
T = [t for t in tmin:tmax]
T_initial = [t for t in tmin-1:tmax]
# Out:
# 6-element Vector{Int64}:
#  0
#  1
#  2
#  3
#  4
#  5

# %%
M = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "P.T. Bio Farma" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])
MR = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "Biological E. Limited" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])
MMR = Dict("Serum Institute of India" => [0.53745, 0.5679, 0.59835, 0.6288, 0.32405], "GlaxoSmithKline" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024], "Merck Sharp & Dohme" => [0.2864, 0.2953, 0.3042, 0.3131, 0.024])

# %%
r_rand = [0.53745 0.5776 0.53745 9999 9999; 0.5679 .82 0.53745 9999 9999; 0.59835 8 0.53745 0.024 9999;;; 0.5679 .52 9999.53745 9999 9999; 0.6288 0.2864 0.53745 9999 9999; 0.2864 0.024 0.53745 9999 9999;;; 0.59835 4 0.53745 9999 9999; 0.2864 4 0.53745 .756 0.756; 0.32405 0.2864 0.53745 0.75 0.56;;; 0.6288 4 0.53745 0.56 9999; 10 4 0.53745 0 0; 15 15 0.53745 0 0;;; 0.32405 0.024 0.53745 0 0; 0.024 8 0.53745 0 0; 30 30 0.53745 0 0]
#r_rand = [5 2; 5 2; 6 6;;; 5 2; 5 2; 6 6;;; 10 4; 10 4; 12 12;;; 10 4; 10 4; 12 12;;; 20 8; 20 8; 24 24]
r = Dict()
for v in 1:length(V)
    for p in 1:length(P)
        for t in 1:length(T)
            println("Vaccine $v, Producer $p, Time $t")
            println(r_rand[v,p,t])
            r[V[v],P[p],T[t]] = r_rand[v,p,t]
        end
    end
end
# Out:
# Vaccine 1, Producer 1, Time 1
# 0.53745
# Vaccine 1, Producer 1, Time 2
# 0.5679
# Vaccine 1, Producer 1, Time 3
# 0.59835
# Vaccine 1, Producer 1, Time 4
# 0.6288
# Vaccine 1, Producer 1, Time 5
# 0.32405
# Vaccine 1, Producer 2, Time 1
# 0.5776
# Vaccine 1, Producer 2, Time 2
# 0.52
# Vaccine 1, Producer 2, Time 3
# 4.0
# Vaccine 1, Producer 2, Time 4
# 4.0
# Vaccine 1, Producer 2, Time 5
# 0.024
# Vaccine 1, Producer 3, Time 1
# 0.53745
# Vaccine 1, Producer 3, Time 2
# 9999.53745
# Vaccine 1, Producer 3, Time 3
# 0.53745
# Vaccine 1, Producer 3, Time 4
# 0.53745
# Vaccine 1, Producer 3, Time 5
# 0.53745
# Vaccine 1, Producer 4, Time 1
# 9999.0
# Vaccine 1, Producer 4, Time 2
# 9999.0
# Vaccine 1, Producer 4, Time 3
# 9999.0
# Vaccine 1, Producer 4, Time 4
# 0.0
# Vaccine 1, Producer 4, Time 5
# 0.0
# Vaccine 1, Producer 5, Time 1
# 9999.0
# Vaccine 1, Producer 5, Time 2
# 9999.0
# Vaccine 1, Producer 5, Time 3
# 9999.0
# Vaccine 1, Producer 5, Time 4
# 0.0
# ...

# %%
import pandas as pd

# Load the CSV file
file_path = 'data/pair_demand_capacity_1scenario+20.csv'
data = pd.read_csv(file_path)

# Initialize dictionary for scenario pairs
expanded_scenario_pairs = {}

# Iterate over the rows and populate the dictionary
for _, row in data.iterrows():
    pair_idx = row['pair_idx']
    category = 'demand' if row['type'] == 'antigen' else 'capacity'
    
    # Remove brackets, split space-separated string, and convert to floats
    values_str = row['values'].strip('[]')
    # values = list(map(float, values_str.split()))
    values_str = row['values'].strip('[]').replace(',', '')
    values = list(map(float, values_str.split()))
    unit = row['unit']
    
    expanded_scenario_pairs.setdefault(pair_idx, {'demand': {}, 'capacity': {}})
    
    for i, value in enumerate(values, 1):
        expanded_scenario_pairs[pair_idx][category].setdefault(i, {})[unit] = value

expanded_scenario_pairs
# Out:
# {1: {'demand': {1: {'Measles': 504116405.1472744,
#     'Mumps': 428797566.4741963,
#     'Rubella': 397534979.30274767,
#     'Diphtheria': 684660182.764577,
#     'Tetanus': 693276219.6641592,
#     'Pertussis': 384795290.1038484,
#     'Hepatitis_B': 71403062.5729035,
#     'Hib': 626618410.6704644,
#     'Polio': 626618410.6704644,
#     'HPV': 22785851.665604666,
#     'Rotavirus': 170974804.04134354,
#     'PCV': 192960279.6359017},
#    2: {'Measles': 441959452.05863553,
#     'Mumps': 313043674.88704294,
#     'Rubella': 280229301.15465266,
#     'Diphtheria': 763520991.9887094,
#     'Tetanus': 771914917.4195288,
#     'Pertussis': 428153042.7523835,
#     'Hepatitis_B': 82354829.66282272,
#     'Hib': 717481444.6596136,
#     'Polio': 717481444.6596136,
#     'HPV': 23144268.484348096,
#     'Rotavirus': 205098574.76406452,
#     'PCV': 230453989.38877094},
#    3: {'Measles': 486590504.32203245,
#     'Mumps': 375415432.6862375,
#     'Rubella': 343637474.91559404,
#     'Diphtheria': 772043635.9284341,
#     'Tetanus': 780452396.9484539,
#     'Pertussis': 434377345.48691523,
#     'Hepatitis_B': 87438322.56965597,
#     'Hib': 750077787.1454425,
#     'Polio': 750077787.1454425,
#     'HPV': 33841675.17809937,
#     'Rotavirus': 214131219.69160584,
#     'PCV': 257775520.17108524},
#    4: {'Measles': 426525206.57763416,
#     'Mumps': 341243918.8943088,
#     'Rubella': 310103511.7870368,
#     'Diphtheria': 732657997.4626857,
#     'Tetanus': 741082883.2057155,
#     'Pertussis': 414058114.3307115,
#     'Hepatitis_B': 82724037.96006192,
#     'Hib': 727965845.6553957,
#     'Polio': 727965845.6553957,
#     'HPV': 89779708.26208037,
#     'Rotavirus': 229631083.08504856,
#     'PCV': 253798547.34546286},
#    5: {'Measles': 465316128.64071184,
#     'Mumps': 359056424.18959457,
#     'Rubella': 330050360.65533435,
#     'Diphtheria': 734486000.8400415,
#     'Tetanus': 738050936.9833555,
#     'Pertussis': 412675621.523375,
#     'Hepatitis_B': 81740320.35168108,
#     'Hib': 729264687.4300618,
#     'Serum_Institute': 478200000.0},
#    2: {'AJ_Vaccines': 6120000.0,
#     'BB_NCIPD': 34680000.0,
#     'Bharat_Biotech': 50520000.0,
#     'Bilthoven': 9540000.0,
#     'Biological_E': 111600000.0,
#     'China_National': 9120000.0,
#     'GSK': 202200000.0,
#     'Haffkine_Bio': 67200000.0,
#     'LG_Chem': 54300000.0,
#     'Merck_Sharp': 18810000.0,
#     'PT_Bio': 9360000.0,
#     'Panacea_Biotec': 64800000.0,
#     'Pfizer': 44880000.0,
#     'Sanofi': 70200000.0,
#     'Serum_Institute': 490800000.0},
#    3: {'AJ_Vaccines': 7140000.0,
#     'BB_NCIPD': 34920000.0,
#     'Bharat_Biotech': 51420000.0,
#     'Bilthoven': 11160000.0,
#     'Biological_E': 112800000.0,
#     'China_National': 9480000.0,
#     'GSK': 221400000.0,
#     'Haffkine_Bio': 68400000.0,
#     'LG_Chem': 56400000.0,
#     'Merck_Sharp': 27500000.000000004,
#     'PT_Bio': 9540000.0,
#     'Panacea_Biotec': 72600000.0,
#     'Pfizer': 43860000.0,
#     'Sanofi': 78600000.0,
#     'Serum_Institute': 512400000.0},
#    4: {'AJ_Vaccines': 7140000.0,
#     'BB_NCIPD': 33000000.0,
#     'Bharat_Biotech': 49800000.0,
#     'Bilthoven': 11100000.0,
#     'Biological_E': 107400000.0,
#     'China_National': 10200000.0,
#     'GSK': 224400000.0,
#     'Haffkine_Bio': 66000000.0,
#     'LG_Chem': 53700000.0,
#     'Merck_Sharp': 73040000.0,
#     'PT_Bio': 9120000.0,
#     'Panacea_Biotec': 71400000.0,
#     'Pfizer': 40140000.0,
#     'Sanofi': 78000000.0,
#     'Serum_Institute': 474600000.0},
#    5: {'AJ_Vaccines': 7080000.0,
#     'BB_NCIPD': 32880000.0,
#     'Bharat_Biotech': 50100000.0,
#     'Bilthoven': 11100000.0,
#     'Biological_E': 106200000.0,
#     'China_National': 10620000.0,
#     'GSK': 238200000.0,
#     'Haffkine_Bio': 66000000.0,
#     'LG_Chem': 53460000.0,
#     'Merck_Sharp': 92950000.00000001,
#     'PT_Bio': 9120000.0,
#     'Panacea_Biotec': 76800000.0,
#     'Pfizer': 41880000.0,
#     'Sanofi': 78000000.0,
#     'Serum_Institute': 490200000.0},
#    6: {'AJ_Vaccines': 7020000.0,
#     'BB_NCIPD': 32700000.0,
#     'Bharat_Biotech': 48420000.0,
#     'Bilthoven': 10920000.0,
#     'Biological_E': 103800000.0,
#     'China_National': 9660000.0,
#     'GSK': 256800000.0,
#     'Haffkine_Bio': 63600000.0,
#     'LG_Chem': 52440000.0,
#     'Merck_Sharp': 64900000.00000001,
#     'PT_Bio': 8940000.0,
#     'Panacea_Biotec': 76200000.0,
#     'Pfizer': 35220000.0,
#     'Sanofi': 76800000.0,
#     'Serum_Institute': 490800000.0},
#    7: {'AJ_Vaccines': 7140000.0,
#     'BB_NCIPD': 32940000.0,
#     'Bharat_Biotech': 3240000.0,
#     'Bilthoven': 11160000.0,
#     'Biological_E': 405000000.0,
#     'China_National': 954000.0,
#     'GSK': 215400000.0,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 53100000.0,
#     'Merck_Sharp': 42350000.0,
#     'PT_Bio': 8280000.0,
#     'Panacea_Biotec': 77400000.0,
#     'Pfizer': 26400000.0,
#     'Sanofi': 59940000.0,
#     'Serum_Institute': 323400000.0},
#    8: {'AJ_Vaccines': 7020000.0,
#     'BB_NCIPD': 32700000.0,
#     'Bharat_Biotech': 3204000.0,
#     'Bilthoven': 10980000.0,
#     'Biological_E': 403200000.0,
#     'China_National': 954000.0,
#     'GSK': 235800000.0,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 52320000.0,
#     'Merck_Sharp': 42460000.0,
#     'PT_Bio': 8220000.0,
#     'Panacea_Biotec': 75600000.0,
#     'Pfizer': 25080000.0,
#     'Sanofi': 58980000.0,
#     'Serum_Institute': 372000000.0},
#    9: {'AJ_Vaccines': 7140000.0,
#     'BB_NCIPD': 33120000.0,
#     'Bharat_Biotech': 3240000.0,
#     'Bilthoven': 11160000.0,
#     'Biological_E': 405000000.0,
#     'China_National': 762000.0,
#     'GSK': 220800000.0,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 52980000.0,
#     'Merck_Sharp': 33770000.0,
#     'PT_Bio': 8340000.0,
#     'Panacea_Biotec': 76200000.0,
#     'Pfizer': 25440000.0,
#     'Sanofi': 60000000.0,
#     'Serum_Institute': 330600000.0},
#    10: {'AJ_Vaccines': 7260000.0,
#     'BB_NCIPD': 33480000.0,
#     'Bharat_Biotech': 3276000.0,
#     'Bilthoven': 11340000.0,
#     'Biological_E': 406200000.0,
#     'China_National': 792000.0,
#     'GSK': 228000000.0,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 53520000.0,
#     'Merck_Sharp': 35090000.0,
#     'PT_Bio': 8400000.0,
#     'Panacea_Biotec': 76200000.0,
#     'Pfizer': 25680000.0,
#     'Sanofi': 61200000.0,
#     'Serum_Institute': 348600000.0}}}}

# %%
expanded_scenario_pairs.keys()
# Out:
# dict_keys([1])

# %%
import json

# Define the file path for the JSON output
json_output_path = 'data/scenario_pairs_new_1_scenario+20.json'

# Write the dictionary to a JSON file
with open(json_output_path, 'w') as json_file:
    json.dump(expanded_scenario_pairs, json_file)

# Provide the file path for download
json_output_path
# Out:
# 'data/scenario_pairs_new_1_scenario+20.json'

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'data/pair_demand_capacity_1scenario+20.csv'
df = pd.read_csv(file_path)

# Create the dictionary with scenarios and their probabilities
scenarios_probabilities = df[['pair_idx', 'pair_probability']].drop_duplicates().set_index('pair_idx')['pair_probability'].to_dict()

json_file_path = 'data/scenario_pair_probabilities_new_1_scenario+20.json'

# Write the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(scenarios_probabilities, json_file, indent=4)

print(f"Scenarios probabilities have been saved to {json_file_path}")
# Out:
# Scenarios probabilities have been saved to data/scenario_pair_probabilities_new_1_scenario+20.json

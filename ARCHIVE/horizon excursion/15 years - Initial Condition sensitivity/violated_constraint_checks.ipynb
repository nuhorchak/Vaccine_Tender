# %%
import json

def load_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

def analyze_iis_constraints(json_data):
    # Check and print constraints excluding those containing {'type': 'ZeroOne'}
    if 'constraints' in json_data:
        for constraint in json_data['constraints']:
            constraint_str = json.dumps(constraint)
            if '{"type": "ZeroOne"}' not in constraint_str:  # Check the JSON string representation
                print(f"Constraint: {constraint}")
    else:
        print("No constraints part found in JSON data.")
    
if __name__ == "__main__":
    file_path = 'errors.json'  # Path to the JSON file
    json_data = load_json_file(file_path)
    analyze_iis_constraints(json_data)
# Out:
# Constraint: {'name': 'c1', 'function': {'type': 'ScalarAffineFunction', 'terms': [{'coefficient': 1.0, 'variable': 'Q[MR,Biological_E,(1, 1)]'}], 'constant': 0.0}, 'set': {'type': 'EqualTo', 'value': 144446638.0}}
# Constraint: {'name': 'c2', 'function': {'type': 'ScalarAffineFunction', 'terms': [{'coefficient': 1.0, 'variable': 'Q[Penta,Biological_E,(1, 1)]'}], 'constant': 0.0}, 'set': {'type': 'EqualTo', 'value': 85901144.0}}
# Constraint: {'name': 'c1_1', 'function': {'type': 'ScalarQuadraticFunction', 'affine_terms': [{'coefficient': 1.0, 'variable': 'Q[DTwP,Biological_E,(1, 1)]'}, {'coefficient': -160100000.0, 'variable': 'W[Biological_E,(1, 1)]'}, {'coefficient': 1.0, 'variable': 'Q[MR,Biological_E,(1, 1)]'}, {'coefficient': 1.0, 'variable': 'Q[Penta,Biological_E,(1, 1)]'}], 'quadratic_terms': [{'coefficient': -16010000.0, 'variable_1': 'L[Biological_E,1]', 'variable_2': 'W[Biological_E,(1, 1)]'}], 'constant': 0.0}, 'set': {'type': 'LessThan', 'upper': 0.0}}
# Constraint: {'function': {'type': 'Variable', 'name': 'Q[DTwP,Biological_E,(1, 1)]'}, 'set': {'type': 'GreaterThan', 'lower': 0.0}}

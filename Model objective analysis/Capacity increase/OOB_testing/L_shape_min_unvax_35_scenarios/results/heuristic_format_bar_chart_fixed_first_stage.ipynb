# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import matplotlib.patches as mpatches

# %% [markdown]
# ### New output format for L shaped results

# %%
with open("DE_L_results_T_10_delta_5_scen_35_trial_1_inv_1_cap._1_cap.inc._1_min_unvax.json") as json_file:
    data = json.load(json_file)

start_DF = pd.read_excel("../data/Starting_point.xlsx", sheet_name="F_start")
# start_DF["Value"] = 1
start_DF.rename(columns={"Antigen": "Antigen", "Starting": "Start", "Ending": "Finish"}, inplace=True)

# %%
start_DF['Fill'] = 'Initial'

# %%
start_DF
# Out:
#         Antigen  Start  Finish     Fill
# 0    Diphtheria      1       1  Initial
# 1       Tetanus      1       1  Initial
# 2           HPV      1       5  Initial
# 3           PCV      1       3  Initial
# 4         Polio      1       1  Initial
# 5       Rubella      1       3  Initial
# 6   Hepatitis_B      1       1  Initial
# 7         Mumps      1       3  Initial
# 8     Pertussis      1       1  Initial
# 9       Measles      1       3  Initial
# 10          Hib      1       1  Initial
# 11    Rotavirus      1       1  Initial
# 12      Tetanus      2       5  Initial
# 13        Polio      2       5  Initial
# 14      Measles      2       4  Initial
# 15    Rotavirus      2       4  Initial
# 16   Diphtheria      2       5  Initial
# 17          Hib      2       5  Initial
# 18  Hepatitis_B      2       4  Initial
# 19      Rubella      2       6  Initial
# 20    Pertussis      2       4  Initial
# 21    Pertussis      3       5  Initial
# 22        Mumps      4       8  Initial
# 23      Measles      4       8  Initial
# 24          PCV      4       4  Initial
# 25    Pertussis      4       6  Initial
# 26        Mumps      5       7  Initial
# 27        Polio      5       8  Initial
# 28    Rotavirus      5       7  Initial
# 29      Rubella      5       8  Initial
# 30          PCV      5       8  Initial
# 31  Hepatitis_B      5       6  Initial
# 32    Pertussis      6      10  Initial
# 33        Polio      6       6  Initial
# 34          PCV      6       9  Initial
# 35      Tetanus      6      10  Initial
# 36   Diphtheria      6      10  Initial
# 37          Hib      6      10  Initial
# 38  Hepatitis_B      6      10  Initial
# 39          HPV      6       9  Initial
# 40          PCV      7       7  Initial
# 41        Mumps      7       9  Initial
# 42      Rubella      7       9  Initial
# 43    Rotavirus      7       9  Initial
# 44    Pertussis      8       9  Initial
# 45      Measles      8      10  Initial
# 46      Rubella      8       9  Initial
# 47          HPV      8      10  Initial
# 48      Rubella      9      10  Initial
# 49          PCV      9       9  Initial
# 50    Rotavirus      9      10  Initial
# 51        Polio      9       9  Initial
# 52        Mumps      9      10  Initial
# 53          HPV      9      10  Initial
# 54          PCV     10      10  Initial
# 55        Polio     10      10  Initial
# 56        Mumps     10      10  Initial
# 57          HPV     10      10  Initial

# %%
# Applying the provided code to filter for the data in 'F'

rows = []

# Parse the dictionary into the desired DataFrame structure using the 'F' key
for antigen, sub_dict in data['F'].items():
    for starting, ending_dict in sub_dict.items():
        for ending, fill in ending_dict.items():
            if fill == 1.0:  # Filter based on the condition that fill == 1.0
                fill_value = 'Full'
            else:
                fill_value = 'None'
            rows.append([antigen, int(starting), int(ending), fill_value])

# Create the DataFrame
df_filtered_F = pd.DataFrame(rows, columns=['Antigen', 'Start', 'Finish', 'Fill'])
df_filtered_F_no_none = df_filtered_F[df_filtered_F['Fill'] != 'None']
df_filtered_F_no_none.to_excel("L_Shape_min_unvax_35_tender_fixed.xlsx")

# %%
# Identify non-overlapping rows based on Starting and Ending
non_overlapping = df_filtered_F_no_none[~df_filtered_F_no_none[['Start', 'Finish']].apply(tuple, axis=1).isin(start_DF[['Start', 'Finish']].apply(tuple, axis=1))]

# Append non-overlapping rows to df1
all_tenders = pd.concat([start_DF, non_overlapping], ignore_index=True)

all_tenders.loc[all_tenders['Fill'] == 'Full', 'Fill'] = 'New'


# Display the updated DataFrame
# all_tenders
all_tenders.loc[all_tenders['Fill'] != 'New']
# Out:
#         Antigen  Start  Finish     Fill
# 0    Diphtheria      1       1  Initial
# 1       Tetanus      1       1  Initial
# 2           HPV      1       5  Initial
# 3           PCV      1       3  Initial
# 4         Polio      1       1  Initial
# 5       Rubella      1       3  Initial
# 6   Hepatitis_B      1       1  Initial
# 7         Mumps      1       3  Initial
# 8     Pertussis      1       1  Initial
# 9       Measles      1       3  Initial
# 10          Hib      1       1  Initial
# 11    Rotavirus      1       1  Initial
# 12      Tetanus      2       5  Initial
# 13        Polio      2       5  Initial
# 14      Measles      2       4  Initial
# 15    Rotavirus      2       4  Initial
# 16   Diphtheria      2       5  Initial
# 17          Hib      2       5  Initial
# 18  Hepatitis_B      2       4  Initial
# 19      Rubella      2       6  Initial
# 20    Pertussis      2       4  Initial
# 21    Pertussis      3       5  Initial
# 22        Mumps      4       8  Initial
# 23      Measles      4       8  Initial
# 24          PCV      4       4  Initial
# 25    Pertussis      4       6  Initial
# 26        Mumps      5       7  Initial
# 27        Polio      5       8  Initial
# 28    Rotavirus      5       7  Initial
# 29      Rubella      5       8  Initial
# 30          PCV      5       8  Initial
# 31  Hepatitis_B      5       6  Initial
# 32    Pertussis      6      10  Initial
# 33        Polio      6       6  Initial
# 34          PCV      6       9  Initial
# 35      Tetanus      6      10  Initial
# 36   Diphtheria      6      10  Initial
# 37          Hib      6      10  Initial
# 38  Hepatitis_B      6      10  Initial
# 39          HPV      6       9  Initial
# 40          PCV      7       7  Initial
# 41        Mumps      7       9  Initial
# 42      Rubella      7       9  Initial
# 43    Rotavirus      7       9  Initial
# 44    Pertussis      8       9  Initial
# 45      Measles      8      10  Initial
# 46      Rubella      8       9  Initial
# 47          HPV      8      10  Initial
# 48      Rubella      9      10  Initial
# 49          PCV      9       9  Initial
# 50    Rotavirus      9      10  Initial
# 51        Polio      9       9  Initial
# 52        Mumps      9      10  Initial
# 53          HPV      9      10  Initial
# 54          PCV     10      10  Initial
# 55        Polio     10      10  Initial
# 56        Mumps     10      10  Initial
# 57          HPV     10      10  Initial

# %%
# First, filter for rows where Fill is 'Full'
df_full_copy = all_tenders.loc[all_tenders['Fill'] != 'New']

# Check for overlaps within each antigen and update 'Fill' to 'Overlap' where necessary
for antigen, group in df_full_copy.groupby('Antigen'):
    sorted_group = group.sort_values(by='Start')
    for i in range(len(sorted_group) - 1):
        current_row = sorted_group.iloc[i]
        next_row = sorted_group.iloc[i + 1]
        # Check if the Ending of the current row overlaps with the Starting of the next row
        if current_row['Finish'] >= next_row['Start']:
            # Update Fill to 'Overlap' for both current and next row
            df_full_copy.loc[current_row.name, 'Fill'] = 'Overlap'
            df_full_copy.loc[next_row.name, 'Fill'] = 'Overlap'

# Display the updated DataFrame with Overlap
# df_full_copy.loc[df_full_copy['Start'] == 1, 'Fill'] = 'Initial'
df_full_copy['Start'] = df_full_copy['Start'] - 1
df_full_copy
# Out:
# <positron-console-cell-7>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#         Antigen  Start  Finish     Fill
# 0    Diphtheria      0       1  Initial
# 1       Tetanus      0       1  Initial
# 2           HPV      0       5  Initial
# 3           PCV      0       3  Initial
# 4         Polio      0       1  Initial
# 5       Rubella      0       3  Overlap
# 6   Hepatitis_B      0       1  Initial
# 7         Mumps      0       3  Initial
# 8     Pertussis      0       1  Initial
# 9       Measles      0       3  Overlap
# 10          Hib      0       1  Initial
# 11    Rotavirus      0       1  Initial
# 12      Tetanus      1       5  Initial
# 13        Polio      1       5  Overlap
# 14      Measles      1       4  Overlap
# 15    Rotavirus      1       4  Initial
# 16   Diphtheria      1       5  Initial
# 17          Hib      1       5  Initial
# 18  Hepatitis_B      1       4  Initial
# 19      Rubella      1       6  Overlap
# 20    Pertussis      1       4  Overlap
# 21    Pertussis      2       5  Overlap
# 22        Mumps      3       8  Overlap
# 23      Measles      3       8  Overlap
# 24          PCV      3       4  Initial
# 25    Pertussis      3       6  Overlap
# 26        Mumps      4       7  Overlap
# 27        Polio      4       8  Overlap
# 28    Rotavirus      4       7  Overlap
# 29      Rubella      4       8  Overlap
# 30          PCV      4       8  Overlap
# 31  Hepatitis_B      4       6  Overlap
# 32    Pertussis      5      10  Overlap
# 33        Polio      5       6  Overlap
# 34          PCV      5       9  Overlap
# 35      Tetanus      5      10  Initial
# 36   Diphtheria      5      10  Initial
# 37          Hib      5      10  Initial
# 38  Hepatitis_B      5      10  Overlap
# 39          HPV      5       9  Overlap
# 40          PCV      6       7  Overlap
# 41        Mumps      6       9  Overlap
# 42      Rubella      6       9  Overlap
# 43    Rotavirus      6       9  Overlap
# 44    Pertussis      7       9  Overlap
# 45      Measles      7      10  Overlap
# 46      Rubella      7       9  Overlap
# 47          HPV      7      10  Overlap
# 48      Rubella      8      10  Overlap
# 49          PCV      8       9  Initial
# 50    Rotavirus      8      10  Overlap
# 51        Polio      8       9  Initial
# 52        Mumps      8      10  Overlap
# 53          HPV      8      10  Overlap
# 54          PCV      9      10  Initial
# 55        Polio      9      10  Initial
# 56        Mumps      9      10  Overlap
# 57          HPV      9      10  Overlap

# %%
all_tenders_new = pd.concat([df_full_copy, all_tenders.loc[all_tenders['Fill'] == 'New']], axis=0)

# %%
df = all_tenders_new

# Define color groups
colors = {
    "MMR Antigens": "blue",
    "Hexa Antigens": "green",
    "HPV": "red",
    "PCV": "purple",
    "Rota": "orange",
}

color_groups = {
    "MMR Antigens": ["Measles", "Mumps", "Rubella"],
    "Hexa Antigens": ["Diphtheria", "Tetanus", "Pertussis", "Hib", "Polio", "Hepatitis_B"],
    "HPV": ["HPV"],
    "PCV": ["PCV"],
    "Rota": ["Rotavirus"],
}

# Create custom legend handles
legend_handles = []
for group, color in colors.items():
    patch = mpatches.Patch(color=color, label=group)
    legend_handles.append(patch)

# Creating a color mapping for each antigen
antigen_colors = {}
for group, antigen_list in color_groups.items():
    for antigen in antigen_list:
        antigen_colors[antigen] = colors[group]

df['Color'] = df['Antigen'].map(antigen_colors)

# Create a mapping of antigens to their group order (based on color groups)
group_order = {group: i for i, group in enumerate(color_groups.keys())}

# Map each antigen to its group
df['Group'] = df['Antigen'].map({antigen: group for group, antigens in color_groups.items() for antigen in antigens})

# Sort the DataFrame by the group order to align with the colors
df['GroupOrder'] = df['Group'].map(group_order)
df_sorted = df.sort_values(by='GroupOrder')

# Plot configuration
plt.rcParams.update(mpl.rcParamsDefault)
plt.rcParams.update(
    {
        "font.family": "serif",
        "font.size": 12,
        "font.weight": "normal",
        "figure.titlesize": "medium",
        "xtick.color": "black",
        "ytick.color": "black",
        "axes.labelcolor": "black",
        "text.color": "black",
        "savefig.dpi": 300,
        "figure.dpi": 150,
        "savefig.bbox": "tight",
    }
)

# Plot the horizontal bar chart with color formatting and black outlines for each segment
plt.figure(figsize=(10, 6))
for i, row in df_sorted.iterrows():
    color = row['Color']
    if row['Fill'] != 'New':
        color = mpl.colors.to_rgba(color, 0.2)  # Darken by reducing transparency
    
    if row["Fill"] == 'Overlap':
        hatch = '//'
    elif row['Fill'] == 'New':
        hatch = '\\'
    elif row['Fill'] == 'None':
        color = 'black'
        hatch = None
    else:
        hatch = None
    
    # Plot the bar with the corresponding properties
    plt.barh(row['Antigen'], row['Finish'] - row['Start'], 
             left=row['Start'], color=color, edgecolor='black', 
             linewidth=1.5, hatch=hatch)

# Add the legend in the upper right corner, outside the plot
plt.legend(handles=legend_handles, title="Antigen Groups", loc="upper left", 
           bbox_to_anchor=(1, 1), borderaxespad=0.)

plt.xlim(0, 10) 
plt.xticks(list(range(1, 11)))
plt.xlabel('Years')
plt.ylabel('Antigen')
plt.title('Stochastic Antigen Tender Schedule - Fixed First Stage')
# plt.grid(True)
plt.tight_layout()
plt.savefig('L_shaped_35_scenario_min_unvax_OOB.pdf', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()

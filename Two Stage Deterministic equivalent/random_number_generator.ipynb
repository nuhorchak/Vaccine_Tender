# %%
include("demand_scenario_generator_mean_vals.jl")
# Out:
# data_generation (generic function with 1 method)

# %%
random_data, mean_data = data_generation(2, "../DATA/antigen_CI_Random_generator.xlsx", true, true)
# Out:
# Generating 2 datasets!
# (DataFrame[12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ PCV          2.29728e8  2.78181e8  2.77731e8  3.4471e8   1.99287e8  3.3 ⋯
#    2 │ Measles      5.0726e8   3.01963e8  2.82048e8  9.77378e8  8.74628e8  6.0
#    3 │ Mumps        3.18915e7  3.75273e7  1.35554e7  2.29844e7  1.2843e7   1.9
#    4 │ HPV          2.89631e7  3.58277e7  4.16327e7  4.67546e7  5.22516e7  6.1
#    5 │ Hib          3.18547e8  3.19586e8  3.1705e8   3.58977e8  4.2807e8   4.2 ⋯
#    6 │ Pertussis    3.57228e8  3.32998e8  2.85959e8  3.55892e8  4.09397e8  3.5
#    7 │ Rotavirus    1.79751e8  1.77384e8  2.60541e8  3.3546e8   4.35109e8  3.7
#    8 │ Polio        5.90312e8  7.1662e8   7.37291e8  5.84875e8  7.14874e8  7.8
# ...

# %%
random_data
# Out:
# 2-element Vector{DataFrame}:
#  12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ PCV          2.29728e8  2.78181e8  2.77731e8  3.4471e8   1.99287e8  3.3 ⋯
#    2 │ Measles      5.0726e8   3.01963e8  2.82048e8  9.77378e8  8.74628e8  6.0
#    3 │ Mumps        3.18915e7  3.75273e7  1.35554e7  2.29844e7  1.2843e7   1.9
#    4 │ HPV          2.89631e7  3.58277e7  4.16327e7  4.67546e7  5.22516e7  6.1
#    5 │ Hib          3.18547e8  3.19586e8  3.1705e8   3.58977e8  4.2807e8   4.2 ⋯
#    6 │ Pertussis    3.57228e8  3.32998e8  2.85959e8  3.55892e8  4.09397e8  3.5
#    7 │ Rotavirus    1.79751e8  1.77384e8  2.60541e8  3.3546e8   4.35109e8  3.7
#    8 │ Polio        5.90312e8  7.1662e8   7.37291e8  5.84875e8  7.14874e8  7.8
# ...

# %%
mean_data
# Out:
# 12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ PCV          2.32139e8  2.51055e8  2.59683e8  3.23792e8  2.55059e8  3.6 ⋯
#    2 │ Measles      5.3114e8   4.11255e8  3.20712e8  7.8572e8   9.65535e8  5.9
#    3 │ Mumps        2.93495e7  2.90553e7  2.22433e7  3.0858e7   2.09263e7  2.6
#    4 │ HPV          2.80898e7  3.59783e7  4.10317e7  4.84701e7  5.56211e7  5.9
#    5 │ Hib          3.11272e8  3.19484e8  3.26214e8  3.72545e8  3.72249e8  3.7 ⋯
#    6 │ Pertussis    3.47857e8  3.15109e8  3.26321e8  3.51923e8  4.19857e8  3.3
#    7 │ Rotavirus    1.78743e8  2.01824e8  2.61837e8  3.90321e8  4.12755e8  4.6
#    8 │ Polio        6.35835e8  6.70083e8  7.57048e8  6.28704e8  8.34963e8  7.4
# ...

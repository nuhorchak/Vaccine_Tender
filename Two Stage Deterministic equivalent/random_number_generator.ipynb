# %%
include("demand_scenario_generator.jl")
# Out:
# data_generation (generic function with 1 method)

# %%
data_generation(100, "../DATA/antigen_CI_Random_generator.xlsx", true)
# Out:
# Generating 100 datasets!
# 100-element Vector{DataFrame}:
#  12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ PCV          2.31217e8  2.73986e8  2.08946e8  2.83154e8  2.6272e8   4.9 ⋯
#    2 │ Measles      5.36054e8  6.67321e8  4.26849e8  6.40364e8  4.11852e8  6.9
#    3 │ Mumps        2.50947e7  2.83719e7  2.33165e7  2.00809e7  2.18944e7  3.2
#    4 │ HPV          2.79819e7  3.45602e7  4.57024e7  4.52492e7  5.02097e7  6.2
#    5 │ Hib          3.14422e8  2.69618e8  3.85843e8  3.75952e8  3.13641e8  3.6 ⋯
#    6 │ Pertussis    3.46388e8  3.90564e8  3.58542e8  3.84483e8  3.97084e8  4.1
#    7 │ Rotavirus    1.71502e8  2.17332e8  3.12657e8  3.83719e8  4.00881e8  2.4
#    8 │ Polio        5.5677e8   6.76671e8  7.96523e8  7.74751e8  9.02825e8  6.2
# ...

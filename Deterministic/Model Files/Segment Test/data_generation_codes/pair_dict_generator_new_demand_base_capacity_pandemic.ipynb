# %%
import pandas as pd

# Load the CSV file
file_path = 'data/pair_demand_capacity_1scenario_15YR_NO_MMR.csv'
data = pd.read_csv(file_path)

# Initialize dictionary for scenario pairs
expanded_scenario_pairs = {}

# Iterate over the rows and populate the dictionary
for _, row in data.iterrows():
    pair_idx = row['pair_idx']
    category = 'demand' if row['type'] == 'antigen' else 'capacity'
    
    # Remove brackets, split space-separated string, and convert to floats
    values_str = row['values'].strip('[]')
    # values = list(map(float, values_str.split()))
    values_str = row['values'].strip('[]').replace(',', '')
    values = list(map(float, values_str.split()))
    unit = row['unit']
    
    expanded_scenario_pairs.setdefault(pair_idx, {'demand': {}, 'capacity': {}})
    
    for i, value in enumerate(values, 1):
        expanded_scenario_pairs[pair_idx][category].setdefault(i, {})[unit] = value

expanded_scenario_pairs
# Out:
# {1: {'demand': {1: {'Diphtheria': 570550152.3038142,
#     'Tetanus': 577730183.053466,
#     'Pertussis': 320662741.753207,
#     'Hepatitis_B': 59502552.14408625,
#     'Hib': 522182008.8920537,
#     'Polio': 522182008.8920537,
#     'HPV': 18988209.72133722,
#     'Rotavirus': 142479003.3677863,
#     'PCV': 160800233.02991807},
#    2: {'Diphtheria': 619539915.6026529,
#     'Tetanus': 626350955.3874788,
#     'Pertussis': 347414023.65496874,
#     'Hepatitis_B': 66824756.29894736,
#     'Hib': 582182282.261939,
#     'Polio': 582182282.261939,
#     'HPV': 18779834.86234023,
#     'Rotavirus': 166422082.736177,
#     'PCV': 186996096.55044705},
#    3: {'Diphtheria': 626455400.7858117,
#     'Tetanus': 633278478.5365579,
#     'Pertussis': 352464577.64274204,
#     'Hepatitis_B': 70949628.8296462,
#     'Hib': 608631764.9670907,
#     'Polio': 608631764.9670907,
#     'HPV': 27459976.61319326,
#     'Rotavirus': 173751395.40052408,
#     'PCV': 209165465.89669368},
#    4: {'Diphtheria': 594496914.5266843,
#     'Tetanus': 601333076.2785748,
#     'Pertussis': 335977048.30469936,
#     'Hepatitis_B': 67124341.09060526,
#     'Hib': 590689585.8937,
#     'Polio': 590689585.8937,
#     'HPV': 72849487.39214571,
#     'Rotavirus': 186328369.91646266,
#     'PCV': 205938451.2702555},
#    5: {'Diphtheria': 595980201.9149964,
#     'Tetanus': 598872879.7333298,
#     'Pertussis': 334855259.2692105,
#     'Hepatitis_B': 66326128.16592105,
#     'Hib': 591743498.4015433,
#     'Polio': 591743498.4015433,
#     'HPV': 92670605.20200755,
#     'Rotavirus': 197668287.62063622,
#     'PCV': 220998668.43915194},
#    6: {'Diphtheria': 587103256.5710243,
#     'Tetanus': 590040117.7710243,
#     'Pertussis': 328035816.40447366,
#     'Hepatitis_B': 64629993.39171051,
#     'Hib': 572502985.5910566,
#     'Polio': 572502985.5910566,
#     'HPV': 64703773.73395889,
#     'Rotavirus': 205652326.6330228,
#     'PCV': 219106581.71571612},
#    7: {'Diphtheria': 593084718.433114,
#     'Tetanus': 596064291.848114,
#     'Pertussis': 331237497.8667105,
#     'Hepatitis_B': 65467500.8481579,
#     'Hib': 130824126.4955653,
#     'Polio': 151396626.4955653,
#     'HPV': 42236974.675196275,
#     'Rotavirus': 209552844.43528977,
#     'PCV': 222271116.4064051},
#    8: {'Diphtheria': 588242927.3280308,
#     'Tetanus': 591261950.0013641,
#     'Pertussis': 328597735.4357895,
#     'Hepatitis_B': 64108778.51236841,
#     'Hib': 128805067.1053376,
#     'Polio': 215227035.9723376,
#     'HPV': 42368434.197219275,
#     'Rotavirus': 207355550.10954678,
#     'PCV': 217335571.50486726},
#    9: {'Diphtheria': 594999405.7426674,
#     'Tetanus': 598056654.4826674,
#     'Pertussis': 331754261.71440786,
#     'Hepatitis_B': 64880245.935592085,
#     'Hib': 131099302.06079172,
#     'Polio': 243358292.50179172,
#     'HPV': 33730466.86672733,
#     'Rotavirus': 209606287.81869888,
#     'PCV': 218764570.77513307},
#    10: {'Diphtheria': 600453889.0383071,
#     'Tetanus': 603543359.2099737,
#     'Pertussis': 334606906.5501974,
#     'Hepatitis_B': 65250732.01177631,
#     'Hib': 133250901.64506109,
#     'Polio': 251394162.53006107,
#     'HPV': 35038544.997919135,
#     'Rotavirus': 211802837.82197365,
#     'PCV': 220234251.13688153},
#    11: {'Diphtheria': 593529816.913942,
#     'Tetanus': 594971085.335096,
#     'Pertussis': 330410815.005491,
#     'Hepatitis_B': 65414837.0288072,
#     'Hib': 135497591.476787,
#     'Polio': 121699026.583433,
#     'HPV': 51677476.1535772,
#     'Rotavirus': 230124637.978656,
#     'PCV': 236335831.314592},
#    12: {'Diphtheria': 592882387.584711,
#     'Tetanus': 593756156.37234,
#     'Pertussis': 329656311.03201,
#     'Hepatitis_B': 65398177.2662483,
#     'Hib': 137720508.746649,
#     'Polio': 189646606.836675,
#     'HPV': 52912902.5767358,
#     'Rotavirus': 237226954.231864,
#     'PCV': 241458509.613146},
#    13: {'Diphtheria': 592234958.255481,
#     'Tetanus': 592541227.409584,
#     'Pertussis': 328901807.058528,
#     'Hepatitis_B': 65381517.5036894,
#     'Hib': 139943426.01651,
#     'Polio': 187323799.510021,
#     'HPV': 54148328.9998945,
#     'Rotavirus': 244329270.485072,
#     'PCV': 246581187.911699},
#    14: {'Diphtheria': 591587528.92625,
#     'Tetanus': 591326298.446828,
#     'Pertussis': 328147303.085046,
#     'Hepatitis_B': 65364857.7411305,
#     'Hib': 142166343.286372,
#     'Polio': 185000992.183367,
#     'HPV': 55383755.4230532,
#     'Rotavirus': 251431586.73828,
#     'PCV': 251703866.210253},
#    15: {'Diphtheria': 590940099.59702,
#     'Tetanus': 590111369.484071,
#     'Pertussis': 327392799.111565,
#     'Hepatitis_B': 65348197.9785716,
#     'Hib': 144389260.556234,
#     'Polio': 182678184.856713,
#     'HPV': 56619181.8462118,
#     'Rotavirus': 258533902.991488,
#     'PCV': 256826544.508807}},
#   'capacity': {1: {'Serum_Institute': 5201000.0,
#     'GSK': 26400000.0,
#     'Biological_E': 52270000.0,
#     'Haffkine_Bio': 8119999.999999999,
#     'Panacea_Biotec': 96900000.0,
#     'Sanofi': 9730000.0,
#     'LG_Chem': 224700000.0,
#     'Bharat_Biotech': 71400000.0,
#     'Pfizer': 55510000.0,
#     'BB_NCIPD': 11830000.0,
#     'Merck_Sharp': 9800000.0,
#     'PT_Bio': 53419999.99999999,
#     'China_National': 43540000.0,
#     'Bilthoven': 63349999.99999999,
#     'AJ_Vaccines': 557900000.0},
#    2: {'Serum_Institute': 7140000.0,
#     'GSK': 20460000.0,
#     'Biological_E': 57939999.99999999,
#     'Haffkine_Bio': 11130000.0,
#     'Panacea_Biotec': 110199999.99999999,
#     'Sanofi': 10640000.0,
#     'LG_Chem': 235899999.99999997,
#     'Bharat_Biotech': 78400000.0,
#     'Pfizer': 63349999.99999999,
#     'BB_NCIPD': 11970000.0,
#     'Merck_Sharp': 10920000.0,
#     'PT_Bio': 65600000.0,
#     'China_National': 52360000.0,
#     'Bilthoven': 81900000.0,
#     'AJ_Vaccines': 572600000.0},
#    3: {'Serum_Institute': 8329999.999999999,
#     'GSK': 20740000.0,
#     'Biological_E': 58989999.99999999,
#     'Haffkine_Bio': 13020000.0,
#     'Panacea_Biotec': 111599999.99999999,
#     'Sanofi': 11060000.0,
#     'LG_Chem': 258299999.99999997,
#     'Bharat_Biotech': 79800000.0,
#     'Pfizer': 65799999.99999999,
#     'BB_NCIPD': 17500000.0,
#     'Merck_Sharp': 11130000.0,
#     'PT_Bio': 74700000.0,
#     'China_National': 51170000.0,
#     'Bilthoven': 91700000.0,
#     'AJ_Vaccines': 597800000.0},
#    4: {'Serum_Institute': 8329999.999999999,
#     'GSK': 28500000.0,
#     'Biological_E': 57100000.0,
#     'Haffkine_Bio': 12950000.0,
#     'Panacea_Biotec': 105299999.99999999,
#     'Sanofi': 11900000.0,
#     'LG_Chem': 261799999.99999997,
#     'Bharat_Biotech': 77000000.0,
#     'Pfizer': 62649999.99999999,
#     'BB_NCIPD': 46480000.0,
#     'Merck_Sharp': 10640000.0,
#     'PT_Bio': 73300000.0,
#     'China_National': 46830000.0,
#     'Bilthoven': 91000000.0,
#     'AJ_Vaccines': 553700000.0},
#    5: {'Serum_Institute': 8259999.999999999,
#     'GSK': 28360000.0,
#     'Biological_E': 57450000.0,
#     'Haffkine_Bio': 12950000.0,
#     'Panacea_Biotec': 103899999.99999999,
#     'Sanofi': 12390000.0,
#     'LG_Chem': 277900000.0,
#     'Bharat_Biotech': 77000000.0,
#     'Pfizer': 62369999.99999999,
#     'BB_NCIPD': 59149999.99999999,
#     'Merck_Sharp': 10640000.0,
#     'PT_Bio': 79600000.0,
#     'China_National': 48860000.0,
#     'Bilthoven': 91000000.0,
#     'AJ_Vaccines': 571900000.0},
#    6: {'Serum_Institute': 8189999.999999999,
#     'GSK': 28150000.0,
#     'Biological_E': 55490000.0,
#     'Haffkine_Bio': 12740000.0,
#     'Panacea_Biotec': 101099999.99999999,
#     'Sanofi': 11270000.0,
#     'LG_Chem': 299600000.0,
#     'Bharat_Biotech': 74200000.0,
#     'Pfizer': 61179999.99999999,
#     'BB_NCIPD': 41300000.0,
#     'Merck_Sharp': 10430000.0,
#     'PT_Bio': 78900000.0,
#     'China_National': 41090000.0,
#     'Bilthoven': 89600000.0,
#     'AJ_Vaccines': 572600000.0},
#    7: {'Serum_Institute': 8329999.999999999,
#     'GSK': 28430000.0,
#     'Biological_E': 2779999.9999999995,
#     'Haffkine_Bio': 13020000.0,
#     'Panacea_Biotec': 452499999.99999994,
#     'Sanofi': 1113000.0,
#     'LG_Chem': 251299999.99999997,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 61949999.99999999,
#     'BB_NCIPD': 26950000.0,
#     'Merck_Sharp': 9660000.0,
#     'PT_Bio': 80300000.0,
#     'China_National': 30799999.999999996,
#     'Bilthoven': 69930000.0,
#     'AJ_Vaccines': 377300000.0},
#    8: {'Serum_Institute': 8189999.999999999,
#     'GSK': 18150000.0,
#     'Biological_E': 2737999.9999999995,
#     'Haffkine_Bio': 12810000.0,
#     'Panacea_Biotec': 450399999.99999994,
#     'Sanofi': 1113000.0,
#     'LG_Chem': 275100000.0,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 61039999.99999999,
#     'BB_NCIPD': 27020000.0,
#     'Merck_Sharp': 9590000.0,
#     'PT_Bio': 78200000.0,
#     'China_National': 29260000.0,
#     'Bilthoven': 68810000.0,
#     'AJ_Vaccines': 434000000.0},
#    9: {'Serum_Institute': 8329999.999999999,
#     'GSK': 28640000.0,
#     'Biological_E': 2779999.9999999995,
#     'Haffkine_Bio': 13020000.0,
#     'Panacea_Biotec': 452499999.99999994,
#     'Sanofi': 889000.0,
#     'LG_Chem': 257599999.99999997,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 61809999.99999999,
#     'BB_NCIPD': 21490000.0,
#     'Merck_Sharp': 9730000.0,
#     'PT_Bio': 78900000.0,
#     'China_National': 29679999.999999996,
#     'Bilthoven': 70000000.0,
#     'AJ_Vaccines': 385700000.0},
#    10: {'Serum_Institute': 8470000.0,
#     'GSK': 29060000.0,
#     'Biological_E': 3821999.9999999995,
#     'Haffkine_Bio': 13230000.0,
#     'Panacea_Biotec': 453899999.99999994,
#     'Sanofi': 923999.9999999999,
#     'LG_Chem': 265999999.99999997,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 62439999.99999999,
#     'BB_NCIPD': 22330000.0,
#     'Merck_Sharp': 9800000.0,
#     'PT_Bio': 78900000.0,
#     'China_National': 29959999.999999996,
#     'Bilthoven': 71400000.0,
#     'AJ_Vaccines': 406700000.0},
#    11: {'Serum_Institute': 9109800.0,
#     'GSK': 27950000.0,
#     'Biological_E': 3821999.9999999995,
#     'Haffkine_Bio': 14238000.0,
#     'Panacea_Biotec': 3821999.9999999995,
#     'Sanofi': 1017114.4035061658,
#     'LG_Chem': 280746666.666667,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 62626666.6666667,
#     'BB_NCIPD': 33012000.0,
#     'Merck_Sharp': 9594666.66666667,
#     'PT_Bio': 86189333.3333334,
#     'China_National': 25475333.3333333,
#     'Bilthoven': 72538666.6666666,
#     'AJ_Vaccines': 420811999.9999996},
#    12: {'Serum_Institute': 9333927.27272727,
#     'GSK': 28361090.9090909,
#     'Biological_E': 3852477.288453311,
#     'Haffkine_Bio': 14590545.4545455,
#     'Panacea_Biotec': 3826320.445203105,
#     'Sanofi': 1158987.595591057,
#     'LG_Chem': 284369696.969697,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 62775151.5151515,
#     'BB_NCIPD': 33813818.1818182,
#     'Merck_Sharp': 9478424.24242424,
#     'PT_Bio': 88372484.8484849,
#     'China_National': 22769939.3939394,
#     'Bilthoven': 71387696.9696969,
#     'AJ_Vaccines': 445251000.0},
#    13: {'Serum_Institute': 9558054.54545454,
#     'GSK': 28772181.8181818,
#     'Biological_E': 3888155.569992305,
#     'Haffkine_Bio': 14943090.9090909,
#     'Panacea_Biotec': 3826418.7209489793,
#     'Sanofi': 1365517.773195763,
#     'LG_Chem': 287992727.272727,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 62923636.3636364,
#     'BB_NCIPD': 34615636.3636364,
#     'Merck_Sharp': 9362181.81818182,
#     'PT_Bio': 90555636.3636364,
#     'China_National': 20064545.4545454,
#     'Bilthoven': 70236727.2727272,
#     'AJ_Vaccines': 435776800.0},
#    14: {'Serum_Institute': 9782181.81818181,
#     'GSK': 29183272.7272727,
#     'Biological_E': 3929168.150864888,
#     'Haffkine_Bio': 15295636.3636364,
#     'Panacea_Biotec': 3822289.837298507,
#     'Sanofi': 1661714.4054408101,
#     'LG_Chem': 291615757.575758,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 63072121.2121212,
#     'BB_NCIPD': 35417454.5454546,
#     'Merck_Sharp': 9245939.39393939,
#     'PT_Bio': 92738787.8787879,
#     'China_National': 17359151.5151515,
#     'Bilthoven': 69085757.5757575,
#     'AJ_Vaccines': 441538200.0},
#    15: {'Serum_Institute': 10006309.0909091,
#     'GSK': 29594363.6363636,
#     'Biological_E': 3975669.9953232114,
#     'Haffkine_Bio': 15648181.8181818,
#     'Panacea_Biotec': 3813942.808289118,
#     'Sanofi': 2086489.152545892,
#     'LG_Chem': 295238787.878788,
#     'Bharat_Biotech': 7420000.0,
#     'Pfizer': 63220606.0606061,
#     'BB_NCIPD': 36219272.7272727,
#     'Merck_Sharp': 9129696.96969697,
#     'PT_Bio': 94921939.3939394,
#     'China_National': 14653757.5757575,
#     'Bilthoven': 67934787.8787878,
#     'AJ_Vaccines': 447299600.0}}}}

# %%
expanded_scenario_pairs.keys()
# Out:
# dict_keys([1])

# %%
import json

# Define the file path for the JSON output
json_output_path = 'data/scenario_pairs_new_1_scenario_15YR_NO_MMR.json'

# Write the dictionary to a JSON file
with open(json_output_path, 'w') as json_file:
    json.dump(expanded_scenario_pairs, json_file)

# Provide the file path for download
json_output_path
# Out:
# 'data/scenario_pairs_new_1_scenario_15YR_NO_MMR.json'

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'data/pair_demand_capacity_1scenario_15YR_NO_MMR.csv'
df = pd.read_csv(file_path)

# Create the dictionary with scenarios and their probabilities
scenarios_probabilities = df[['pair_idx', 'pair_probability']].drop_duplicates().set_index('pair_idx')['pair_probability'].to_dict()

json_file_path = 'data/scenario_pair_probabilities_new_15YR_NO_MMR.json'

# Write the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(scenarios_probabilities, json_file, indent=4)

print(f"Scenarios probabilities have been saved to {json_file_path}")
# Out:
# Scenarios probabilities have been saved to data/scenario_pair_probabilities_new_15YR_NO_MMR.json

# %%
import pandas as pd

# Load the CSV file
file_path = 'data/pair_demand_capacity_1scenario_11SEP.csv'
data = pd.read_csv(file_path)

# Initialize dictionary for scenario pairs
expanded_scenario_pairs = {}

# Iterate over the rows and populate the dictionary
for _, row in data.iterrows():
    pair_idx = row['pair_idx']
    category = 'demand' if row['type'] == 'antigen' else 'capacity'
    
    # Remove brackets, split space-separated string, and convert to floats
    values_str = row['values'].strip('[]')
    # values = list(map(float, values_str.split()))
    values_str = row['values'].strip('[]').replace(',', '')
    values = list(map(float, values_str.split()))
    unit = row['unit']
    
    expanded_scenario_pairs.setdefault(pair_idx, {'demand': {}, 'capacity': {}})
    
    for i, value in enumerate(values, 1):
        expanded_scenario_pairs[pair_idx][category].setdefault(i, {})[unit] = value

expanded_scenario_pairs
# Out:
# {1: {'demand': {1: {'Measles': 420097004.28939533,
#     'Mumps': 357331305.3951636,
#     'Rubella': 331279149.4189564,
#     'Diphtheria': 570550152.3038142,
#     'Tetanus': 577730183.053466,
#     'Pertussis': 320662741.753207,
#     'Hepatitis_B': 59502552.14408625,
#     'Hib': 522182008.8920537,
#     'Polio': 522182008.8920537,
#     'HPV': 18988209.72133722,
#     'Rotavirus': 142479003.3677863,
#     'PCV': 160800233.02991807},
#    2: {'Measles': 368299543.3821963,
#     'Mumps': 260869729.0725358,
#     'Rubella': 233524417.62887722,
#     'Diphtheria': 636267493.3239245,
#     'Tetanus': 643262431.1829407,
#     'Pertussis': 356794202.2936529,
#     'Hepatitis_B': 68629024.71901894,
#     'Hib': 597901203.8830113,
#     'Polio': 597901203.8830113,
#     'HPV': 19286890.403623413,
#     'Rotavirus': 170915478.97005376,
#     'PCV': 192044991.15730911},
#    3: {'Measles': 405492086.93502706,
#     'Mumps': 312846193.9051979,
#     'Rubella': 286364562.4296617,
#     'Diphtheria': 643369696.6070285,
#     'Tetanus': 650376997.457045,
#     'Pertussis': 361981121.23909605,
#     'Hepatitis_B': 72865268.80804664,
#     'Hib': 625064822.6212021,
#     'Polio': 625064822.6212021,
#     'HPV': 28201395.981749475,
#     'Rotavirus': 178442683.0763382,
#     'PCV': 214812933.47590438},
#    4: {'Measles': 355437672.1480285,
#     'Mumps': 284369932.411924,
#     'Rubella': 258419593.155864,
#     'Diphtheria': 610548331.2189047,
#     'Tetanus': 617569069.3380963,
#     'Pertussis': 345048428.60892624,
#     'Hepatitis_B': 68936698.3000516,
#     'Hib': 606638204.7128298,
#     'Polio': 606638204.7128298,
#     'HPV': 74816423.55173364,
#     'Rotavirus': 191359235.90420714,
#     'PCV': 211498789.45455238},
#    5: {'Measles': 387763440.53392655,
#     'Mumps': 299213686.82466215,
#     'Rubella': 275041967.2127786,
#     'Diphtheria': 612071667.3667012,
#     'Tetanus': 615042447.4861296,
#     'Pertussis': 343896351.26947916,
#     'Hepatitis_B': 68116933.6264009,
#     'Hib': 607720572.8583848,
#     'Polio': 607720572.8583848,
#     'HPV': 95172711.54246174,
#     'Rotavirus': 203005331.3863934,
#     'Biological_E': 204600000.00000003,
#     'China_National': 16720000.000000002,
#     'GSK': 370700000.00000006,
#     'Haffkine_Bio': 123200000.00000001,
#     'LG_Chem': 99550000.00000001,
#     'Merck_Sharp': 18810000.0,
#     'PT_Bio': 17160000.0,
#     'Panacea_Biotec': 118800000.00000001,
#     'Pfizer': 82280000.0,
#     'Sanofi': 128700000.00000001,
#     'Serum_Institute': 899800000.0000001},
#    3: {'AJ_Vaccines': 13090000.000000002,
#     'BB_NCIPD': 64020000.00000001,
#     'Bharat_Biotech': 84843000.0,
#     'Bilthoven': 20460000.0,
#     'Biological_E': 206800000.00000003,
#     'China_National': 17380000.0,
#     'GSK': 405900000.00000006,
#     'Haffkine_Bio': 125400000.00000001,
#     'LG_Chem': 103400000.00000001,
#     'Merck_Sharp': 27500000.000000004,
#     'PT_Bio': 17490000.0,
#     'Panacea_Biotec': 133100000.00000001,
#     'Pfizer': 80410000.0,
#     'Sanofi': 144100000.0,
#     'Serum_Institute': 939400000.0000001},
#    4: {'AJ_Vaccines': 13090000.000000002,
#     'BB_NCIPD': 60500000.00000001,
#     'Bharat_Biotech': 82170000.0,
#     'Bilthoven': 20350000.0,
#     'Biological_E': 196900000.00000003,
#     'China_National': 18700000.0,
#     'GSK': 411400000.00000006,
#     'Haffkine_Bio': 121000000.00000001,
#     'LG_Chem': 98450000.00000001,
#     'Merck_Sharp': 73040000.0,
#     'PT_Bio': 16720000.000000002,
#     'Panacea_Biotec': 130900000.00000001,
#     'Pfizer': 73590000.0,
#     'Sanofi': 143000000.0,
#     'Serum_Institute': 870100000.0000001},
#    5: {'AJ_Vaccines': 12980000.000000002,
#     'BB_NCIPD': 60280000.00000001,
#     'Bharat_Biotech': 82665000.0,
#     'Bilthoven': 20350000.0,
#     'Biological_E': 194700000.00000003,
#     'China_National': 19470000.0,
#     'GSK': 436700000.00000006,
#     'Haffkine_Bio': 121000000.00000001,
#     'LG_Chem': 98010000.00000001,
#     'Merck_Sharp': 92950000.00000001,
#     'PT_Bio': 16720000.000000002,
#     'Panacea_Biotec': 140800000.0,
#     'Pfizer': 76780000.0,
#     'Sanofi': 143000000.0,
#     'Serum_Institute': 898700000.0000001},
#    6: {'AJ_Vaccines': 12870000.000000002,
#     'BB_NCIPD': 59950000.00000001,
#     'Bharat_Biotech': 79893000.0,
#     'Bilthoven': 20020000.0,
#     'Biological_E': 190300000.00000003,
#     'China_National': 17710000.0,
#     'GSK': 470800000.00000006,
#     'Haffkine_Bio': 116600000.00000001,
#     'LG_Chem': 96140000.00000001,
#     'Merck_Sharp': 64900000.00000001,
#     'PT_Bio': 16390000.000000002,
#     'Panacea_Biotec': 139700000.0,
#     'Pfizer': 64570000.00000001,
#     'Sanofi': 140800000.0,
#     'Serum_Institute': 899800000.0000001},
#    7: {'AJ_Vaccines': 13090000.000000002,
#     'BB_NCIPD': 60390000.00000001,
#     'Bharat_Biotech': 5346000.0,
#     'Bilthoven': 20460000.0,
#     'Biological_E': 742500000.0000001,
#     'China_National': 1749000.0000000002,
#     'GSK': 394900000.00000006,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 97350000.00000001,
#     'Merck_Sharp': 42350000.0,
#     'PT_Bio': 15180000.000000002,
#     'Panacea_Biotec': 141900000.0,
#     'Pfizer': 48400000.00000001,
#     'Sanofi': 109890000.00000001,
#     'Serum_Institute': 592900000.0},
#    8: {'AJ_Vaccines': 12870000.000000002,
#     'BB_NCIPD': 59950000.00000001,
#     'Bharat_Biotech': 5286600.0,
#     'Bilthoven': 20130000.0,
#     'Biological_E': 739200000.0000001,
#     'China_National': 1749000.0000000002,
#     'GSK': 432300000.00000006,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 95920000.00000001,
#     'Merck_Sharp': 42460000.0,
#     'PT_Bio': 15070000.000000002,
#     'Panacea_Biotec': 138600000.0,
#     'Pfizer': 45980000.0,
#     'Sanofi': 108130000.00000001,
#     'Serum_Institute': 682000000.0},
#    9: {'AJ_Vaccines': 13090000.000000002,
#     'BB_NCIPD': 60720000.00000001,
#     'Bharat_Biotech': 5346000.0,
#     'Bilthoven': 20460000.0,
#     'Biological_E': 742500000.0000001,
#     'China_National': 1397000.0,
#     'GSK': 404800000.00000006,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 97130000.00000001,
#     'Merck_Sharp': 33770000.0,
#     'PT_Bio': 15290000.000000002,
#     'Panacea_Biotec': 139700000.0,
#     'Pfizer': 46640000.00000001,
#     'Sanofi': 110000000.00000001,
#     'Serum_Institute': 606100000.0},
#    10: {'AJ_Vaccines': 13310000.000000002,
#     'BB_NCIPD': 61380000.00000001,
#     'Bharat_Biotech': 5405400.0,
#     'Bilthoven': 20790000.0,
#     'Biological_E': 744700000.0000001,
#     'China_National': 1452000.0000000002,
#     'GSK': 418000000.00000006,
#     'Haffkine_Bio': 0.0,
#     'LG_Chem': 98120000.00000001,
#     'Merck_Sharp': 35090000.0,
#     'PT_Bio': 15400000.000000002,
#     'Panacea_Biotec': 139700000.0,
#     'Pfizer': 47080000.00000001,
#     'Sanofi': 112200000.00000001,
#     'Serum_Institute': 639100000.0}}}}

# %%
expanded_scenario_pairs.keys()
# Out:
# dict_keys([1])

# %%
import json

# Define the file path for the JSON output
json_output_path = 'data/scenario_pairs_new_1_scenario_11SEP.json'

# Write the dictionary to a JSON file
with open(json_output_path, 'w') as json_file:
    json.dump(expanded_scenario_pairs, json_file)

# Provide the file path for download
json_output_path
# Out:
# 'data/scenario_pairs_new_1_scenario_11SEP.json'

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'data/pair_demand_capacity_1scenario_11SEP.csv'
df = pd.read_csv(file_path)

# Create the dictionary with scenarios and their probabilities
scenarios_probabilities = df[['pair_idx', 'pair_probability']].drop_duplicates().set_index('pair_idx')['pair_probability'].to_dict()

json_file_path = 'data/scenario_pair_probabilities_new_11SEP.json'

# Write the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(scenarios_probabilities, json_file, indent=4)

print(f"Scenarios probabilities have been saved to {json_file_path}")
# Out:
# Scenarios probabilities have been saved to data/scenario_pair_probabilities_new_11SEP.json

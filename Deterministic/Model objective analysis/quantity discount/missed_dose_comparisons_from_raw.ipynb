# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
import matplotlib as mpl

import matplotlib.cm as cm

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_1_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
UG_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in UG_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE1_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_2_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
SB_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in SB_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE2_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_3_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE3_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_4_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE4_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_5_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE5_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_6_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE6_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_7_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE7_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_8_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE8_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_9_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE9_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_10_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE10_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
# with open('results/MVP_DE_results_T_10_delta_5_scen_1_trial_11_inv_1_cap._1_cap.inc._1.json', 'r') as file:
with open('MVP_DE_results_T_10_delta_5_scen_1_trial_1_inv_1_cap._1_cap.inc._1.json', 'r') as file:
    second_dataset = json.load(file)
MP_s_data = second_dataset.get("S", None)


# Initialize a dictionary to accumulate scenario-level sums
scenario_sums = defaultdict(float)

# Loop over the nested structure S[antigen][year][scenario]
for antigen_dict in MP_s_data.values():
    for year_dict in antigen_dict.values():
        for scenario, value in year_dict.items():
            scenario_sums[scenario] += value

# Convert the result to a DataFrame for display
DE1_scenario_sum_df = pd.DataFrame(list(scenario_sums.items()), columns=["Scenario", "Total_Value"]).sort_values("Scenario")

# %%
DE1_scenario_sum_df
# Out:
#   Scenario  Total_Value
# 0        1  661403605.0

# %%
# Combine both datasets into a DataFrame for plotting
# combined_data = pd.DataFrame({
#     'Scenario': SB_scenario_sum_df['Scenario'],
#     'Dataset 1': UG_scenario_sum_df['Total_Value'],
#     'Dataset 2': SB_scenario_sum_df['Total_Value'].values,
#     'Dataset 3': MP_scenario_sum_df['Total_Value'].values
# })

# # Data for the bar chart
# data_values = [
#     combined_data['Dataset 1'].iloc[0],
#     combined_data['Dataset 2'].iloc[0],
#     combined_data['Dataset 3'].iloc[0]
# ]

# Combine all datasets into a single DataFrame
combined_data = pd.DataFrame({
    'Scenario': DE1_scenario_sum_df['Scenario'],
    **{f'Dataset {i}': eval(f'DE{i}_scenario_sum_df["Total_Value"]') for i in range(11, 12)}
})

# Data for the bar chart
data_values = [combined_data[f'Dataset {i}'].iloc[0] for i in range(11, 12)]
labels = [f'Dataset {i}' for i in range(11, 12)]

# labels = ['Base Capacity/Demand', 'Base Capacity/Demand + 7%', 'Base Capacity/Demand + 8%']
labels = [
    'Base Capacity/Demand',
    # 'Base Capacity/Demand + 1%',
    # 'Base Capacity/Demand + 2%',
    # 'Base Capacity/Demand + 3%',
    # 'Base Capacity/Demand + 4%',
    # 'Base Capacity/Demand + 5%',
    # 'Base Capacity/Demand + 6%',
    # 'Base Capacity/Demand + 7%',
    # 'Base Capacity/Demand + 8%',
    # 'Base Capacity/Demand + 9%',
    # 'Base Capacity/Demand + 10%'
]


# Create a bar chart
plt.figure(figsize=(10, 6))
# plt.bar(labels, data_values, color=['skyblue', 'lightcoral', 'lightgreen'])
colors = mpl.colormaps.get_cmap('tab10').colors  # New syntax

plt.bar(labels, data_values, color=colors)
# plt.xticks(rotation=-90)
plt.xticks(rotation=45, ha='right')


# Add title and labels
plt.title('SB Model: Missed Doses v Demand Increases', fontsize=16)
plt.ylabel('Missed Doses', fontsize=14)

# Set 5 horizontal grid lines by choosing 5 y-ticks
y_min, y_max = plt.ylim()
plt.yticks(np.linspace(y_min, y_max, 6), fontsize=12)
plt.grid(axis='y')
plt.show()

# Save the figure
# plt.savefig('SB_Missed_doses_Demand_increase_analysis.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)

# %%
# Data from the provided table
data = {
    'F Objective': [2.65E+09, 2.65E+09, 2.65E+09, 2.65E+09, 2.71E+09, 2.04E+09, 2.04E+09, 2.67E+09, 2.67E+09, 2.67E+09, 2.64E+09],
    'Q Objective': [2.35E+10, 2.38E+10, 2.45E+10, 2.47E+10, 2.52E+10, 2.52E+10, 2.59E+10, 2.68E+10, 2.68E+10, 2.65E+10, 2.61E+10],
    'S Objective': [5.60E+09, 7.06E+09, 8.95E+09, 1.27E+10, 1.59E+10, 1.99E+10, 2.27E+10, 2.54E+10, 3.00E+10, 3.58E+10, 4.23E+10],
    'I Objective': [7.39E+07, 7.30E+07, 7.51E+07, 7.70E+07, 8.46E+07, 8.64E+07, 8.81E+07, 1.08E+08, 1.12E+08, 1.13E+08, 1.02E+08],
    'Total Objective': [3.18E+10, 3.36E+10, 3.61E+10, 4.01E+10, 4.39E+10, 4.72E+10, 5.07E+10, 5.49E+10, 5.96E+10, 6.51E+10, 7.12E+10]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create a time index (assuming rows are sequential time points)
df['Time'] = range(1, len(df) + 1)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Time'], df['F Objective'], label='F Objective', marker='o')
plt.plot(df['Time'], df['Q Objective'], label='Q Objective', marker='o')
plt.plot(df['Time'], df['S Objective'], label='S Objective', marker='o')
plt.plot(df['Time'], df['I Objective'], label='I Objective', marker='o')
plt.plot(df['Time'], df['Total Objective'], label='Total Objective', marker='o')

# Customize the plot
plt.xlabel('Trial')
plt.ylabel('Objective Value')
plt.title('Objective Values Over Trials')
plt.legend()
plt.grid(True)
plt.xticks(df['Time'])  # Set x-axis ticks to trial numbers

# Use scientific notation for y-axis
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

# Save the plot
plt.savefig('objective_values_plot.png', dpi=300, bbox_inches='tight')
plt.close()

# %%
# Combine both datasets into a DataFrame for plotting
combined_data = pd.DataFrame({
    'Scenario': SB_scenario_sum_df['Scenario'],
    'Dataset 1': UG_scenario_sum_df['Total_Value'],
    'Dataset 2': SB_scenario_sum_df['Total_Value'].values,
    'Dataset 3': MP_scenario_sum_df['Total_Value'].values
})

# # combined_data["Dataset 1"] *= 1000

# # Create a double box plot for the two datasets
# plt.figure(figsize=(10, 6))
# plt.boxplot([combined_data['Dataset 1'], combined_data['Dataset 2'], combined_data['Dataset 3']], labels=['UNICEF-GAVI', 'Social Benefit', 'Max Profit'], patch_artist=True)
# plt.title('Model Missed Dose Comparison')
# plt.ylabel('Missed Doses')
# plt.grid(True)
# plt.savefig('model_triad_missed_dose_comparison2.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
# plt.show()

plt.figure(figsize=(10, 6))
plt.boxplot(
    [combined_data['Dataset 1'], combined_data['Dataset 2'], combined_data['Dataset 3']],
    labels=['UNICEF-GAVI', 'Social Benefit', 'Max Profit'],
    patch_artist=True
)

# plt.title('Model Missed Dose Comparison')
plt.ylabel('Missed Doses', fontsize=14)

# Set 5 horizontal grid lines by choosing 5 y-ticks
y_min, y_max = plt.ylim()
plt.yticks(np.linspace(y_min, y_max, 5), fontsize=12)
plt.grid(axis='y')

plt.savefig('model_triad_missed_dose_comparison_seed4.jpg', bbox_inches='tight', pad_inches=0.1, dpi=600)
plt.show()

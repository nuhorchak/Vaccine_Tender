# %%
import json
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from collections import defaultdict
import json

# %%
with open('min_unvax_base.json', 'r') as file:
    data = json.load(file)

# %%
S_data = data['S']
S_data_by_scenario = defaultdict(lambda: defaultdict(lambda: defaultdict(dict)))

# Iterate through current structure and move the scenario to the top level
for antigen, years in S_data.items():
    for year, scenarios in years.items():
        for scenario, value in scenarios.items():
            S_data_by_scenario[scenario][year][antigen] = value

# Convert to a regular dictionary for easy use
S_data_by_scenario = dict(S_data_by_scenario)

# %%
S_data_by_scenario
# Out:
# {'5': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 567086.9406449973,
#                            'Measles': 1037493.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 804975.8,
#                            'Polio': 679744.5140658119,
#                            'Diphtheria': 1291013.0000000023,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 30708.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 278983.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 383236.75471081166,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '9': defaultdict(dict,
#                           {'PCV': 723605.9406449973,
#                            'Measles': 1124383.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1729347.7,
#                            'Polio': 1277883.814065812,
#                            'Diphtheria': 1946828.1000000024,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 75297.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 390629.3406449973,
#                            'Measles': 388881.99999999965,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 238193.0,
#                            'Polio': 447433.31406581186,
#                            'Diphtheria': 793222.0000000026,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 189768.99999999965}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 51379.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 1561285.9406449972,
#                            'Measles': 1121945.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1903258.7,
#                            'Polio': 2006130.8140658112,
#                            'Diphtheria': 2526994.1000000034,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '35': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 24248.000000001513,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 139002.59535579896,
#                            'Polio': 7468.772661867784,
#                            'Diphtheria': 19285.8,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 572298.9406449908,
#                            'Measles': 372659.9999999982,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1043663.8,
#                            'Polio': 495798.12737267505,
#                            'Diphtheria': 471364.0000000036,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 55213.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 37355.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 109951.44064499333,
#                            'Measles': 141007.99999999872,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 465290.0,
#                            'Polio': 21123.172661862918,
#                            'Diphtheria': 121010.75471081276,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 71359.99999999872}),
#               '9': defaultdict(dict,
#                           {'PCV': 641209.9406449933,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1498230.7,
#                            'Polio': 859931.4273726682,
#                            'Diphtheria': 1654234.1000000066,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 499058.3406449908,
#                            'Measles': 151890.99999999802,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 590372.0,
#                            'Polio': 514778.92737267504,
#                            'Diphtheria': 309968.00000000396,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 1551.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 776196.9406449933,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1647933.7,
#                            'Polio': 1081087.4273726672,
#                            'Diphtheria': 2023909.1000000075,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '16': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 133173.99999999907,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 165649.99535579895,
#                            'Polio': 49923.827338126895,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 341559.94064499135,
#                            'Measles': 566199.9999999992,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1168564.8,
#                            'Polio': 709255.7820489341,
#                            'Diphtheria': 720354.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 32320.0,
#                            'Rubella': 36352.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 89318.44064499205,
#                            'Measles': 454638.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 472564.0,
#                            'Polio': 205400.82733812212,
#                            'Diphtheria': 200738.75471081212,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 5016.000000001048}),
#               '9': defaultdict(dict,
#                           {'PCV': 574284.9406449914,
#                            'Measles': 464911.9999999992,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1748701.7,
#                            'Polio': 1216673.0820489342,
#                            'Diphtheria': 645838.1,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 378724.3406449914,
#                            'Measles': 578650.999999999,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 610229.0,
#                            'Polio': 565197.5820489342,
#                            'Diphtheria': 346934.0000000018,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 28318.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 965664.9406449914,
#                            'Measles': 549082.9999999981,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 2187455.7,
#                            'Polio': 1732002.0820489333,
#                            'Diphtheria': 309657.1000000008,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '20': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 15195.000000001513,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 137761.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 719119.9406449929,
#                            'Measles': 71834.9999999986,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 918366.8,
#                            'Polio': 937198.7820489332,
#                            'Diphtheria': 543093.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 202715.9999999978}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 20963.0,
#                            'Rubella': 0.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 204524.44064499333,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 228881.0,
#                            'Polio': 255321.82733812195,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 117708.0}),
#               '9': defaultdict(dict,
#                           {'PCV': 1207582.940644993,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1706252.7,
#                            'Polio': 1139461.0820489333,
#                            'Diphtheria': 1732038.0999999968,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 13500.999999999185}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 561356.3406449929,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 274873.0,
#                            'Polio': 701213.582048934,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 34317.99999999779}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 93830.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 37934.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 1695418.940644993,
#                            'Measles': 654407.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 2413934.7,
#                            'Polio': 1695527.0820489323,
#                            'Diphtheria': 2945079.0999999978,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 173661.99999999919})}),
#  '12': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 138161.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 94467.89535579298,
#                            'Polio': 169134.58870358943,
#                            'Diphtheria': 340470.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 232918.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 854614.9406449932,
#                            'Measles': 63328.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1095683.5999999936,
#                            'Polio': 1109517.8434143972,
#                            'Diphtheria': 1097659.799999998,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 231507.99999999907}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 20963.0,
#                            'Rubella': 0.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 342663.44064499333,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 315763.0999999943,
#                            'Polio': 439475.58870357776,
#                            'Diphtheria': 481314.5547108165,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 212865.0}),
#               '9': defaultdict(dict,
#                           {'PCV': 1339583.9406449958,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1883569.4999999935,
#                            'Polio': 1306652.1434143903,
#                            'Diphtheria': 2276231.900000001,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 50799.999999999534}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 696851.3406449934,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 452189.7999999941,
#                            'Polio': 874333.6434143973,
#                            'Diphtheria': 546360.7999999978,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 63109.999999998836}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 35972.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 37934.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 1825987.9406449958,
#                            'Measles': 654407.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 2591251.4999999935,
#                            'Polio': 1861636.1434143893,
#                            'Diphtheria': 3491305.9000000013,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 210960.99999999953})}),
#  '30': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 16576.000000002387,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 139573.5953557989,
#                            'Polio': 0.0,
#                            'Diphtheria': 41099.7068086419,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 572298.9406449908,
#                            'Measles': 376809.99999999907,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1038538.8,
#                            'Polio': 507157.26151945035,
#                            'Diphtheria': 472234.0000000025,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 57984.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 37355.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 116359.44064499368,
#                            'Measles': 136660.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 465861.0,
#                            'Polio': 26804.306808638386,
#                            'Diphtheria': 120799.75471081171,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 67012.0}),
#               '9': defaultdict(dict,
#                           {'PCV': 641209.9406449933,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1492170.7,
#                            'Polio': 872594.5615194434,
#                            'Diphtheria': 1650219.1000000054,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 499058.3406449908,
#                            'Measles': 153269.99999999878,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 585247.0,
#                            'Polio': 525926.0615194504,
#                            'Diphtheria': 307878.0000000025,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 1551.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 776196.9406449933,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1641873.7,
#                            'Polio': 1092184.5615194426,
#                            'Diphtheria': 2022289.1000000061,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '24': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 134072.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 179246.59535580006,
#                            'Polio': 22530.39999999659,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 355635.9406449911,
#                            'Measles': 565756.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1170240.8,
#                            'Polio': 710295.5999999924,
#                            'Diphtheria': 712266.3547108122,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 32320.0,
#                            'Rubella': 36352.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 98659.34064499114,
#                            'Measles': 454637.99999999953,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 474724.0,
#                            'Polio': 209325.09999999282,
#                            'Diphtheria': 195870.75471081253,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 4117.999999999534}),
#               '9': defaultdict(dict,
#                           {'PCV': 587029.9406449911,
#                            'Measles': 466066.0000000023,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1750377.7,
#                            'Polio': 1213299.8999999925,
#                            'Diphtheria': 641061.454710809,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 1598.0000000023283}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 392800.34064499114,
#                            'Measles': 579549.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 612273.0,
#                            'Polio': 565015.3999999926,
#                            'Diphtheria': 339058.3547108123,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 28318.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 976157.9406449911,
#                            'Measles': 552434.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 2187962.7,
#                            'Polio': 1728628.899999992,
#                            'Diphtheria': 304055.4547108099,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '28': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 138190.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 158524.99535579767,
#                            'Polio': 51377.30680864479,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 353375.9406449892,
#                            'Measles': 576000.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1168363.8,
#                            'Polio': 722225.2615194488,
#                            'Diphtheria': 709416.0000000051,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 32320.0,
#                            'Rubella': 36352.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 110788.44064499176,
#                            'Measles': 454638.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
# ...
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 75297.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 406162.3406449911,
#                            'Measles': 388881.9999999987,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 240952.0,
#                            'Polio': 452801.75471081166,
#                            'Diphtheria': 797262.3068086412,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 189768.99999999965}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 51379.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 1571980.9406449911,
#                            'Measles': 1122864.9999999977,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1908208.7,
#                            'Polio': 2011323.254710811,
#                            'Diphtheria': 2540736.4068086413,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '10': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 24248.000000001513,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 129891.2874421273,
#                            'Polio': 0.0,
#                            'Diphtheria': 47957.6,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 572298.9406449912,
#                            'Measles': 364752.9999999978,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1042702.8,
#                            'Polio': 494125.8467971357,
#                            'Diphtheria': 472891.00000000297,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 58583.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 37355.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 109951.4406449931,
#                            'Measles': 124591.99999999767,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 466098.0,
#                            'Polio': 28700.892086324166,
#                            'Diphtheria': 121722.75471081288,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 54943.99999999767}),
#               '9': defaultdict(dict,
#                           {'PCV': 641209.9406449938,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1496499.7,
#                            'Polio': 856040.1467971288,
#                            'Diphtheria': 1653133.1000000057,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 499058.34064499126,
#                            'Measles': 140613.99999999756,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 588240.0,
#                            'Polio': 514580.6467971358,
#                            'Diphtheria': 310215.00000000297,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 1551.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 776196.9406449938,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1646202.7,
#                            'Polio': 1075418.146797128,
#                            'Diphtheria': 2025001.1000000066,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})}),
#  '4': defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>,
#              {'5': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 140599.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 190775.59535579896,
#                            'Polio': 9322.959355009836,
#                            'Diphtheria': 3280.000000000233,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '8': defaultdict(dict,
#                           {'PCV': 351118.9406449894,
#                            'Measles': 578406.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1168219.8,
#                            'Polio': 694295.5140658186,
#                            'Diphtheria': 711125.0000000035,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '1': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 32320.0,
#                            'Rubella': 36352.0}),
#               '0': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '6': defaultdict(dict,
#                           {'PCV': 102123.44064499193,
#                            'Measles': 457047.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 473574.0,
#                            'Polio': 203533.55935500702,
#                            'Diphtheria': 194826.7547108126,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '9': defaultdict(dict,
#                           {'PCV': 585630.9406449894,
#                            'Measles': 477938.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 1748356.7,
#                            'Polio': 1197064.8140658187,
#                            'Diphtheria': 631907.1000000021,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 819.0}),
#               '3': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '7': defaultdict(dict,
#                           {'PCV': 388283.3406449894,
#                            'Measles': 586076.9999999993,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 610293.0,
#                            'Polio': 549493.3140658187,
#                            'Diphtheria': 336117.00000000343,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '4': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0}),
#               '2': defaultdict(dict,
#                           {'PCV': 0.0,
#                            'Measles': 0.0,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 0.0,
#                            'Polio': 0.0,
#                            'Diphtheria': 0.0,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 28318.0,
#                            'Rubella': 0.0}),
#               '10': defaultdict(dict,
#                           {'PCV': 976541.9406449894,
#                            'Measles': 561289.9999999985,
#                            'Mumps': 0.0,
#                            'HPV': 0.0,
#                            'Hib': 0.0,
#                            'Pertussis': 0.0,
#                            'Rotavirus': 2185941.7,
#                            'Polio': 1712562.8140658182,
#                            'Diphtheria': 300141.1000000044,
#                            'Hepatitis_B': 0.0,
#                            'Tetanus': 0.0,
#                            'Rubella': 0.0})})}

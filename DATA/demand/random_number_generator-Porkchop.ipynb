# %%
include("demand_scenario_generator_mean_vals.jl")
# Out:
# data_generation (generic function with 1 method)

# %%
random_data, mean_data = data_generation(50, "../DATA/antigen_CI_Random_generator.xlsx", true, true)
# Out:
# Generating 50 datasets!
# (DataFrame[12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Measles      4.06138e8  6.89037e8  6.38709e8  5.98038e8  1.03606e9  8.7 ⋯
#    2 │ Mumps        3.23814e7  1.81461e7  2.60593e7  4.61162e7  2.96168e7  7.4
#    3 │ Rubella      3.33343e8  3.46985e8  4.00379e8  8.33846e8  2.06533e8  6.3
#    4 │ Diphtheria   5.85906e8  6.49273e8  4.72845e8  8.99039e8  7.5906e8   1.1
#    5 │ Tetanus      7.02952e8  5.87005e8  6.5472e8   6.79066e8  6.09445e8  5.5 ⋯
#    6 │ Pertussis    3.51612e8  3.14711e8  3.51818e8  3.01021e8  2.79096e8  2.5
#    7 │ Hepatitis_B  4.4797e8   3.55707e8  4.90824e8  2.9067e8   3.24766e8  2.8
#    8 │ Hib          2.85152e8  3.42772e8  2.99253e8  3.13268e8  3.41172e8  3.5
# ...

# %%
random_data[50]
# Out:
# 12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Measles      4.45751e8  2.65128e8  5.36509e8  4.92033e8  9.04151e8  9.8 ⋯
#    2 │ Mumps        2.71933e7  3.63363e7  5.35171e7  4.92921e7  2.49985e7  7.7
#    3 │ Rubella      4.06606e8  4.99281e8  2.63856e8  2.40493e8  2.21673e8  4.7
#    4 │ Diphtheria   7.77077e8  5.612e8    7.94636e8  8.16152e8  1.01879e9  1.5
#    5 │ Tetanus      6.35216e8  7.03187e8  6.07943e8  6.0297e8   6.66965e8  5.8 ⋯
#    6 │ Pertussis    3.63476e8  3.95013e8  3.68265e8  3.2891e8   4.07964e8  3.3
#    7 │ Hepatitis_B  3.22339e8  3.59746e8  4.65525e8  5.28497e8  4.88332e8  4.1
#    8 │ Hib          2.74227e8  2.86791e8  2.9306e8   2.63071e8  2.66557e8  3.0
# ...

# %%
mean_data
# Out:
# 12×11 DataFrame
#  Row │ Vaccine      1          2          3          4          5          6   ⋯
#      │ String       Float64    Float64    Float64    Float64    Float64    Flo ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Measles      4.73962e8  5.38836e8  5.99182e8  6.0887e8   7.06415e8  7.1 ⋯
#    2 │ Mumps        2.73812e7  3.06244e7  3.35271e7  3.47462e7  3.71993e7  4.1
#    3 │ Rubella      3.71772e8  4.271e8    4.56679e8  4.73701e8  5.537e8    5.9
#    4 │ Diphtheria   6.74155e8  7.01381e8  7.92597e8  8.09055e8  9.34878e8  1.0
#    5 │ Tetanus      6.42191e8  6.49211e8  6.67772e8  6.53717e8  6.64509e8  6.7 ⋯
#    6 │ Pertussis    3.57643e8  3.55154e8  3.57799e8  3.63153e8  3.60056e8  3.7
#    7 │ Hepatitis_B  3.84042e8  3.85327e8  3.99969e8  4.00662e8  4.37334e8  4.0
#    8 │ Hib          3.00685e8  3.15436e8  3.32753e8  3.31239e8  3.45067e8  3.4
# ...
